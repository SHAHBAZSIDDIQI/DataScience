# %%
#This Notebook purpose is to generate user representation linearly using SVD on the resultant user matrix 
# then Non linearly using Graph and deep walk method
# The last section also incorporates code incase there is an update required to the user representation formed using non-linear method

# %%
import pandas as pd
import numpy as np
import re
import random
from nltk.corpus import stopwords
import networkx as nx
import math
from tqdm import tqdm
from sklearn.decomposition import PCA
from numpy import array
from numpy import diag
from numpy import zeros
from scipy.linalg import svd
from sklearn.decomposition import TruncatedSVD
from gensim.models import Word2Vec
import warnings

# %%
stop_words = set(stopwords.words('english'))
punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
#lemmatizer = WordNetLemmatizer()

# %%
#### Following Functions will extract important users mentioned or indicated to form nodes or vertices of Matrix

#user name are mentioned in URL of the columns "Twitter Reply to","Twitter Retweet of"
def getUserFromUrl(Urlstr):
    #print(Urlstr)
    tok = Urlstr.split('/')
    return tok[3]


#Declaring some global variables
All_User_for_Graph = set()   # Will consider all the users into account if mentioned tweeted retweeted for all the rows
All_OccuranceList = []
BigList = []
#-----

def GetTweetRetweetfromRow(row):
    All_User_for_Graph.add(row['AUTHOR_ID'])
    lis = []
    if(row["Thread Entry Type"] == 'post'):
        return lis
    else:
        ReTweetList = row["Twitter Retweet of"]
        if(len(ReTweetList) >0):
            for reTweet in ReTweetList:
                if(pd.isnull(reTweet)):
                    pass
                else:
                    name = getUserFromUrl(reTweet)
                    lis.append(name)
                    All_User_for_Graph.add(name)
        ReplyList = row['Twitter Reply to']
        if(len(ReplyList) >0):
            for reply in ReplyList:
                if(pd.isnull(reply)):
                    pass
                else:
                    name = getUserFromUrl(reply)
                    lis.append(name)
                    All_User_for_Graph.add(name)
        return list(set(lis))
                
def AllMentionedUser(row):
    All_User_for_Graph.add(row['AUTHOR_ID'])
    lis = []
    tweetList = row["Snippet"]
    for tweet in tweetList:
        lis.extend(re.findall(r"@(\w+)",str(tweet)))
    All_User_for_Graph.update(lis)
    return list(set(lis))

def AllConnections(row):
    conn_lis = []
    conn_lis.append(row['AUTHOR_ID'])
    conn_lis.extend(row['TweetReTweetUser'])
    conn_lis.extend(row['AllMentioneduser'])
    return list(set(conn_lis))

# %%
###### Important using the same PPI score based method as used in co-occurance matrix ---
###--- formula  = log ( (count(w,c) / count(w) * count(c)) * N  )
### N is total Number of users 
def UpdateGraphsonBasisofUsers(user,AllUserList,GraphMatrix):
    total_lis = []
    for lis in BigList:
        if(lis.count(user) >0):
            total_lis.extend(lis)
    k = list(set(total_lis))
    for usr in k:
        if(usr == user):
            pass
        else:
            countwc = total_lis.count(usr)
            countw = All_OccuranceList.count(user)
            countc = All_OccuranceList.count(usr)
            N = len(AllUserList)
            tem = (countwc * N) / (countc * countw)
            score = np.log(tem)
            index_user = AllUserList.index(user)
            index_usr = AllUserList.index(usr)
            GraphMatrix[index_user][index_usr] = score
            GraphMatrix[index_usr][index_user] = score
    return GraphMatrix

# %%
#Read and process the Training data
df = pd.read_excel(r'C:\Users\SHAHBAZ\Desktop\study mat\research papers\New folder\New folder\20200507_Cardiology_HCP_Data.xlsx')
Embedding_Column_Name = ["AUTHOR_ID", "AUTHOR_NAME","TRANS_AUTHOR_BIO","Account Type","Location Name","Gender","Mentioned Authors","Tags","Twitter Reply to","Twitter Retweet of","Thread Entry Type","Snippet"]
Main_DF = df[Embedding_Column_Name]
Main_DF = Main_DF.groupby('AUTHOR_ID',as_index= False)["AUTHOR_NAME","TRANS_AUTHOR_BIO","Account Type","Location Name","Gender","Mentioned Authors","Tags","Twitter Reply to","Twitter Retweet of","Thread Entry Type","Snippet"].agg(lambda x: list(x))

# %%
#### Making a cleaner dataframe ####
for columName in Embedding_Column_Name[1:]:
    for _,x in Main_DF.iterrows():
        x[columName] = list(set(x[columName]))

# %%
#Getting additional user information from the data:
Main_DF['TweetReTweetUser'] = [GetTweetRetweetfromRow(x) for _,x in Main_DF.iterrows()]
Main_DF['AllMentioneduser'] = [AllMentionedUser(x) for _,x in Main_DF.iterrows()]  
Main_DF['AllConnection'] = [AllConnections(x) for _,x in Main_DF.iterrows()] 
for _,x in Main_DF.iterrows():
    All_OccuranceList.extend(x['AllConnection'])
    BigList.append(x['AllConnection'])

# %%
test_df = Main_DF[["AUTHOR_ID","TRANS_AUTHOR_BIO","Snippet","AllConnection"]]
test_df.head()
# Out:
#          AUTHOR_ID                                   TRANS_AUTHOR_BIO  \
# 0            0moba  [EM Physician | @Dartmouth MD MBA | Errand boy...
# 1      1600ronnell                                            [RN4L🖤]
# 2        1963Kelli  [Geek Mom/Feminist/Hiker surrounded by fellow ...
# 3       1EyeSmart1  [Male. Physician. Independent Thinker. Pro USA...
# 4  1HopelesslyHope  [Makeup and Beauty Fanatic,  Lover of Pretty F...
#
#                                              Snippet  \
# 0  [@docneto Ha my brother don’t say this one. Pa...
# 1  [RT @fox5dc Coronavirus now killing more Ameri...
# 2  [RT @koolkaryn ‘Imagine Having Ability to Do T...
# 3  [RT @BusyBrain_Very COVID-19 has now surpassed...
# 4  [RT @CNN Pharmaceutical company Novo Nordisk s...
#
#                              AllConnection
# 0            [docneto, victorr_ugo, 0moba]
# 1                    [1600ronnell, fox5dc]
# 2  [dailysoundnfury, 1963Kelli, koolkaryn]
# 3             [BusyBrain_Very, 1EyeSmart1]
# 4                   [1HopelesslyHope, CNN]

# %%
test_df.to_csv('test.csv',header=True,index=False)

# %%
####### Creating and Processing Graph Matrix to generate user representation ###############
GraphMatrix = np.zeros((len(All_User_for_Graph),len(All_User_for_Graph)))
All_User = list(All_User_for_Graph)
for i in range(len(All_User)):
    GraphMatrix = UpdateGraphsonBasisofUsers(All_User[i],All_User,GraphMatrix)
    if((i % 500) == 0):
        print("Run epoch " + str(i) + " / " + str(len(All_User)))

# %%
#####Applying SVD to reduce dimensions###############
U, s, VT = svd(Graph)
Sigma = zeros((Graph.shape[0], Graph.shape[1]))
Sigma[:Graph.shape[0], :Graph.shape[0]] = diag(s)
# select
n_elements = 250    #Number of dimension of Embedding  tested with 500,375,300 best with 250
Sigma = Sigma[:, :n_elements]
VT = VT[:n_elements, :]
Graph_Embedding = U.dot(Sigma)

# %%
########## Alternate fasted dimension reduction using SVD Truncated 
svd = TruncatedSVD(n_components=250)
svd.fit(Graph)
result = svd.transform(Graph)
#print(result)

# %%
########Saving Matrix for later use since SVD is time consuming on such huge dimension of Matrix ###########
Savefilepath = "C:/Users/SHAHBAZ/ZS UserEmbedding/AutoEncoderInputUserMatrix/"

fileName = Savefilepath + "GraphEmbedding_UserDoc_Matrix.txt"
np.savetxt(fileName,result,fmt='%.8f') 

fileName = Savefilepath + "Graphs_U_Matrix.txt"
np.savetxt(fileName,U,fmt='%.8f') 

fileName = Savefilepath + "Graphs_Sig_Matrix.txt"
np.savetxt(fileName,s,fmt='%.8f') 

fileName = Savefilepath + "Graphs_VT_Matrix.txt"
np.savetxt(fileName,VT,fmt='%.8f') 

fileName = Savefilepath + "GraphUsers.txt"
np.savetxt(fileName,All_User, delimiter=" ", newline = "\n", fmt="%s")

# %%
############## Implementation of Graphical Neural Network using deep walk approach ##################

# %%
#####These methods helps to define key submodule of entire process
#Idea is to generate corpus like structure applying random walks between nodes 
#Passing this corpus to skip gram model to obtain node based embedding

# %%
def CreateTargetConnection(authorid):
    totalList= []
    for lis in BigList:
        if(lis.count(authorid) > 0):
            totalList.extend(lis)
    k = list(filter((authorid).__ne__, totalList))
    return k 

def get_randomwalk(node,path_length):
    random_walk = [node]
    for i in range(path_length-1):
        temp = list(G.neighbors(node))
        temp = list(set(temp) - set(random_walk))    
        if len(temp) == 0:
            break

        random_node = random.choice(temp)
        random_walk.append(random_node)
        node = random_node
        
    return random_walk

# %%
#Not all columns are needed to create the Graphs, a source node and target nodes are needed 
New_DF = Main_DF[["AUTHOR_ID","AllConnection"]]
New_DF['Target_Connection'] = ""
New_DF['Target_Connection'] = [CreateTargetConnection(x['AUTHOR_ID']) for _,x in New_DF.iterrows()]
# Out:
# C:\Users\SHAHBAZ\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\SHAHBAZ\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
#New_DF.to_csv('Graph_based.csv',index=False,header=True)
All_User = list(All_User_for_Graph)
len(All_User)
# Out:
# 11621

# %%
### Creating graph and adding nodes###
G = nx.Graph()
for user in All_User:
    G.add_node(user)
    
### Connecting the edges for users who are linked ####
for _,x in New_DF.iterrows():
    source = x['AUTHOR_ID']
    lis = x['Target_Connection']
    
    for target in lis:
        G.add_edge(source, target)

# %%
G.edges()
# Out:
# EdgeView([('AustinChiangMD', 'AASLDPresident'), ('AustinChiangMD', 'MamaDoctorJones'), ('AustinChiangMD', 'JohnVargoMD'), ('AustinChiangMD', 'MarkPochapin'), ('AustinChiangMD', 'kmergener'), ('AustinChiangMD', 'willsuh76'), ('AustinChiangMD', 'arghavan_salles'), ('AustinChiangMD', 'acgme'), ('AustinChiangMD', 'aoglasser'), ('AustinChiangMD', 'RealDoctorMike'), ('MDhockey2119', 'Kaimandante'), ('ethanjweiss', 'AmiBhattMD'), ('ethanjweiss', 'DrDave01'), ('ethanjweiss', 'DrRamonIssa'), ('ethanjweiss', 'DrSidMukherjee'), ('ethanjweiss', 'EricTopol'), ('ethanjweiss', 'HamidGhanbariMD'), ('ethanjweiss', 'HeartOTXHeartMD'), ('ethanjweiss', 'JKhambhati'), ('ethanjweiss', 'JakeKushnerMD'), ('ethanjweiss', 'KevinH_PhD'), ('ethanjweiss', 'LisaRosenbaum17'), ('ethanjweiss', 'MikeAlbertMD'), ('ethanjweiss', 'NirUrielMD'), ('ethanjweiss', 'PaulVarosy'), ('ethanjweiss', 'SA_Diabetes'), ('ethanjweiss', 'bschermd'), ('ethanjweiss', 'cadiulus'), ('ethanjweiss', 'davidludwigmd'), ('ethanjweiss', 'daviesbj'), ('ethanjweiss', 'drandyphung'), ('ethanjweiss', 'foundmyfitness'), ('ethanjweiss', 'drericwestman'), ('ethanjweiss', 'BenBikmanPhD'), ('ethanjweiss', 'gerdosi'), ('ethanjweiss', 'LDLskeptic2'), ('ethanjweiss', 'garytaubes'), ('ethanjweiss', 'Mangan150'), ('ethanjweiss', 'DietDoctor'), ('ethanjweiss', 'NickdeCusa'), ('ethanjweiss', 'tednaiman'), ('ethanjweiss', 'JimJohnsonSci'), ('ethanjweiss', 'DrEenfeldt'), ('ethanjweiss', 'tmprowell'), ('ethanjweiss', 'AliveCor'), ('ethanjweiss', 'DanielJDrucker'), ('ethanjweiss', 'Cell_Metabolism'), ('ethanjweiss', 'OmronHealthUS'), ('ethanjweiss', 'MattFlowers_PhD'), ('ethanjweiss', 'MichelleCardel'), ('ethanjweiss', 'RachelPerryLab1'), ('ethanjweiss', 'MouseCentral'), ('ethanjweiss', 'PaulTitchenell'), ('ethanjweiss', 'john_thyfault'), ('ethanjweiss', 'SudhaBiddinger'), ('ethanjweiss', 'medicalaxioms'), ('ethanjweiss', 'skathire'), ('ethanjweiss', 'jasonwasfy'), ('ethanjweiss', 'chadinabhan'), ('ethanjweiss', 'iamritu'), ('ethanjweiss', 'MassGeneralNews'), ('ethanjweiss', 'NEJM'), ('ethanjweiss', 'ACCMass'), ('ethanjweiss', 'traynor_kate'), ('ethanjweiss', 'AACVPR'), ('ethanjweiss', 'CardioSmart'), ('ethanjweiss', 'MGHHeartHealth'), ('ethanjweiss', 'pnatarajanmd'), ('ethanjweiss', 'rfsquared'), ('ethanjweiss', 'hkazemi83'), ('ethanjweiss', 'CircAHA'), ('ethanjweiss', 'harvardmed'), ('ethanjweiss', 'JACCJournals'), ('ethanjweiss', 'VamsiMootha'), ('ethanjweiss', 'nmarrouche'), ('ethanjweiss', 'HRSonline'), ('ethanjweiss', 'ErinMichos'), ('ethanjweiss', 'MGH_RI'), ('ethanjweiss', 'gtsayer'), ('ethanjweiss', 'emoryheart'), ('ethanjweiss', 'davidslotwiner'), ('ethanjweiss', 'David84632245'), ('ethanjweiss', 'drsuneet'), ('ethanjweiss', 'CellCellPress'), ('ethanjweiss', 'ASPCardio'), ('ethanjweiss', 'purviparwani'), ('glv70', 'JoeySalads'), ('CedricMBrightMD', 'AmberJohnsonMD'), ('CedricMBrightMD', 'CardioOncology'), ('CedricMBrightMD', 'DocBanks84'), ('CedricMBrightMD', 'EimanJahangir'), ('CedricMBrightMD', 'EmilyGuhl'), ('jackieaj', 'Troy_McD_UBC'), ('jackieaj', 'Aashiq_Kachroo'), ('mdaymon00', 'AOC'), ('josephflaherty', 'varma_ashwin97'), ('RobertKennedyJr', 'CarnivoreMD'), ('RobertKennedyJr', 'allwarriormen'), ('RobertKennedyJr', 'drcateshanahan'), ('EmilyVanDuyne', 'ninaturner'), ('EmilyVanDuyne', 'diabetesalish'), ('EmilyVanDuyne', 'DrDooleyMD'), ('EmilyVanDuyne', 'briebriejoy'), ('RyanLundergan', 'AyannaPressley'), ('Teleneurology', 'AlsaiedTarek'), ('Teleneurology', 'AmiBhattMD'), ('Teleneurology', 'DBelardoMD'), ('Teleneurology', 'DrJayMohan'), ('Teleneurology', 'DrJenniferCo_Vu'), ('Teleneurology', 'DrMarthaGulati'), ('Teleneurology', 'DrQuinnCapers4'), ('Teleneurology', 'DrToniyaSingh'), ('Teleneurology', 'FredWuMD'), ('Teleneurology', 'KTamirisaMD'), ('Teleneurology', 'PushpaShivaram'), ('Teleneurology', 'ShafkatAnwar'), ('Teleneurology', 'arghavan_salles'), ('Teleneurology', 'arwmd'), ('Teleneurology', 'cardioPCImom'), ('Teleneurology', 'drjohnm'), ('Teleneurology', 'drmaggarwal'), ('Teleneurolo ...

# %%
#### Implementing random walk ####
all_nodes = list(G.nodes())

random_walks = []
for n in tqdm(all_nodes):
    for i in range(10):
        random_walks.append(get_randomwalk(n,10))
warnings.filterwarnings('ignore')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 11621/11621 [00:09<00:00, 1272.89it/s]

# %%
random_walks
# Out:
# [['AustinChiangMD',
#   'RealDoctorMike',
#   'willsuh76',
#   'jwmhoulton',
#   'purviparwani',
#   'TKDsosyal',
#   'DrLaxmiMehta',
#   'VietHeartPA',
#   'leenhapong',
#   'JJRyanMD'],
#  ['AustinChiangMD',
#   'arghavan_salles',
#   'theheartorg',
#   'drstaceyrosen',
#   'DNewmanToker',
#   'DaktariJay',
#   'PushpaShivaram',
#   'DrJayMohan',
#   'SCMRorg',
#   'HeartBobH'],
#  ['AustinChiangMD',
#   'MarkPochapin',
#   'aoglasser',
#   'willsuh76',
#   'LoggheMD',
#   'venkmurthy',
#   'JNCjournal',
#   'djc795',
#   'DrTGupta',
#   'sandylewis'],
#  ['AustinChiangMD',
#   'AASLDPresident',
#   'arghavan_salles',
#   'jwmhoulton',
#   'willsuh76',
#   'KaulP',
#   'FrederickWelt',
#   'HFnursemaghee',
#   'BidmcCvi',
#   'mangion11'],
#  ['AustinChiangMD',
#   'AASLDPresident',
#   'arghavan_salles',
#   'SharonneHayes',
#   'angwoyno',
#   'DrLaxmiMehta',
#   'edwardmillermd',
#   'AHAMeetings',
#   'AnumSaeedMD',
#   'PCIsurgeon'],
#  ['AustinChiangMD',
#   'MarkPochapin',
#   'AASLDPresident',
#   'arghavan_salles',
#   'SanjayDivakaran',
#   'DocStrom',
#   'alessia_gimelli',
#   'HeartBobH',
#   'drmalissawood',
#   'drmaggarwal'],
#  ['AustinChiangMD', 'RealDoctorMike', 'MarkPochapin', 'DrMaraK'],
#  ['AustinChiangMD',
#   'acgme',
#   'DrSheilaSahni',
#   'Almanfi_Cardio',
#   'KaulP',
#   'Vetrovec',
#   'purviparwani',
#   'arwmd',
#   'PushpaShivaram',
#   'ACCinTouch'],
#  ['AustinChiangMD',
#   'JohnVargoMD',
#   'MarkPochapin',
#   'willsuh76',
#   'DrSamGirgis',
#   'DrRobDavidson',
#   'drjasonfung',
#   'HealthcareWen'],
#  ['AustinChiangMD',
#   'kmergener',
#   'MarkPochapin',
#   'RealDoctorMike',
#   'arghavan_salles',
#   'SCADalliance',
#   'NitiCardio',
#   'YaleCardiology',
#   'venkmurthy',
#   'alessia_gimelli'],
#  ['MDhockey2119',
#   'Kaimandante',
#   'GiRLiEGiRL524',
#   'IlhanMN',
#   'JustWebbbb',
#   'MsPackyetti',
#   'gkatz',
#   'jessvanb'],
#  ['MDhockey2119',
#   'Kaimandante',
#   'SamsaraJose',
#   'MsPackyetti',
#   'DrRamonEsparza'],
#  ['MDhockey2119',
#   'Kaimandante',
#   'sabineruth',
#   'MsPackyetti',
#   'Bemavis1',
#   'IlhanMN',
#   'diygeochemist'],
#  ['MDhockey2119', 'Kaimandante', 'racheal_rhamy'],
#  ['MDhockey2119', 'Kaimandante', 'DrLearnALot', 'rezaaslan'],
#  ['MDhockey2119', 'Kaimandante', 'Botoan1'],
#  ['MDhockey2119', 'Kaimandante', 'madiihobson'],
#  ['MDhockey2119', 'Kaimandante', 'MDMApants'],
#  ['MDhockey2119',
#   'Kaimandante',
#   'SuzeQKnits',
#   'LongfellowJean',
#   'MPRnews',
#   'jimabeler',
#   'LittleSenator',
#   'ScottPettyMN',
#   '_RyanWinkler',
#   'lizzyb_binkert'],
#  ['MDhockey2119',
#   'Kaimandante',
#   'strungoutwired',
#   'MsPackyetti',
#   'crypticbrunette'],
#  ['ethanjweiss',
#   'gtsayer',
#   'NirUrielMD',
#   'AndrewJSauer',
#   'JGrapsa',
#   'MichaelMegalyMD',
#   'SABOURETCardio',
#   'DrJMieres',
#   'DrBhanuMishra1',
#   'drstaceyrosen'],
#  ['ethanjweiss',
#   'AliveCor',
#   'MikeAlbertMD',
#   'ColleenHuberNMD',
#   'KetoHiking',
#   'CarnivoreMD',
#   'TheLancetInfDis',
#   'LizaWhyatt',
#   'humanOS_me',
#   'mike_lustgarten'],
#  ['ethanjweiss',
#   'ErinMichos',
#   'KevinBSneed',
#   'KTamirisaMD',
#   'dmljmd',
#   'avolgman',
#   'ACCmediacenter',
#   'bcostelloMD',
#   'DocSavageTJU',
#   'HafizaKMD'],
#  ['ethanjweiss',
#   'MikeAlbertMD',
#   'IngrahamAngle',
#   'barbarabwatkins',
#   'wonhunglow23',
#   'ad_hominem2'],
#  ['ethanjweiss',
#   'JACCJournals',
#   'TxID_Edu',
#   'NephroGuy',
#   'kidney_boy',
#   'AtulBaliMD',
#   'hswapnil',
#   'JochenReiser',
#   'escardio',
#   'fitmslax'],
#  ['ethanjweiss',
#   'DrRamonIssa',
#   'DietDoctor',
#   'RobertLustigMD',
#   'rethinkingMD'],
#  ['ethanjweiss',
#   'SA_Diabetes',
#   'MouseCentral',
#   'EricTopol',
#   'f2harrell',
#   'AmericanHeartJ',
#   'djc795',
#   'KTamirisaMD',
#   'DrAnumMinhas',
#   'ASabanayagamMD'],
#  ['ethanjweiss',
#   'DrRamonIssa',
#   'DrEenfeldt',
#   'davidludwigmd',
#   'DrPaulMason',
#   'campgrow',
#   'nypost',
#   'elLeonSordo',
#   'ameeniis'],
#  ['ethanjweiss',
#   'drericwestman',
#   'drandyphung',
#   'ProfTimNoakes',
#   'UnbridledMd',
#   'kari_jerge',
#   'RBlockMD',
#   'kksheld',
#   'EricTopol',
#   'martinmckee'],
#  ['ethanjweiss',
#   'daviesbj',
#   'medicalaxioms',
#   'GoRedForWomen',
#   'avolgman',
#   'geoffrey_rubin',
#   'beaverspharmd',
#   'ACCinTouch',
#   'CoronaryDoc',
#   'RBP0612'],
#  ['glv70', 'JoeySalads', 'mdpUSA1'],
#  ['glv70', 'JoeySalads', 'Jagged1969'],
#  ['glv70', 'JoeySalads', 'senormet17'],
#  ['glv70', 'JoeySalads', 'Evelyn31721', 'EthicsMake'],
#  ['glv70', 'JoeySalads', 'MarciMdn', 'Cernovich', 'RebelChick1111'],
#  ['glv70', 'JoeySalads', 'Evelyn31721', 'denisewu'],
#  ['glv70', 'JoeySalads', 'senormet17'],
#  ['glv70', 'JoeySalads', '57Delmar', 'tweettruth2me'],
#  ['glv70',
#   'JoeySalads',
#   'paulsperry_',
#   'KathleenHawk4',
#   'Jacquel42750745',
#   'gatewaypundit',
#   'ManvelMom',
#   'catturd2',
#   'frank_melone'],
#  ['glv70', 'JoeySalads', 'Jagged1969'],
#  ['CedricMBrightMD',
#   'EmilyGuhl',
#   'CynthiaTaub',
#   'atunuguntla1',
#   'mirvatalasnag',
#   'purviparwani',
#   'CardioOncology',
#   'drahmedmohsen85',
#   'drmaggarwal',
#   'anjleem'],
#  ['CedricMBrightMD',
#   'DocBanks84',
#   'EmilyGuhl',
#   'blackdoctor_org',
#   'EimanJahangir',
#   'VUMChealth',
#   'CardioOncology',
#   'Vilavaite',
#   'EstefaniaOS',
#   'ACCOregon'],
#  ['CedricMBrightMD',
#   'EmilyGuhl',
#   'RichaGuptaMD',
#   'kfaridiMD',
#   'VUMC_heart',
#   'ShafkatAnwar',
#   'MassGeneralNews',
#   'PushpaShivaram',
#   'krychtiukmd',
#   'NitiCardio'],
#  ['CedricMBrightMD',
#   'CardioOncology',
#   'noshreza',
#   'beaverspharmd',
#   'DrPRao',
#   'manesh_patelMD',
#   'DanMarkMD',
#   'precisiondiagn4',
#   'AmericanHeartJ',
#   'f2harrell'],
#  ['CedricMBrightMD',
#   'EmilyGuhl',
#   'AMLandryMD',
#   'EimanJahangir',
#   'DrWinkfield',
#   'CardioOncology',
#   'HeartInstitute',
#   'edwardmillermd',
#   'HeartBobH',
#   'PCapranzano'],
#  ['CedricMBrightMD',
#   'EmilyGuhl',
#   'DrWinkfield',
#   'DocBanks84',
#   'sanjayvdesai',
#   'EimanJahangir',
#   'DrCameronWebb',
#   'AmberJohnsonMD',
#   'iamDiddy',
#   'CardioOncology'],
#  ['CedricMBrightMD',
#   'AmberJohnsonMD',
#   'UPMC',
#   'EimanJahangir',
#   'BoydDamp',
#   'DocBanks84',
#   'VUMC_heart',
#   'McMullanMike',
#   'menachem_j',
#   'drmaggarwal'],
#  ['CedricMBrightMD',
#   'AmberJohnsonMD',
#   'dr_adeebq',
#   'jelevenson',
#   'mpt',
#   'skathire',
#   'IAmDrIbrahim',
#   'mpsotka',
#   'American_Heart',
#   'michaelwoodhci'],
#  ['CedricMBrightMD',
#   'CardioOncology',
#   'Dr_Mike_Fradley',
#   'AnaBaracCardio',
#   'DSadlerMD',
#   'PennMedNews',
#   'KBerlacher',
#   'purviparwani',
#   'AndrewR_DO',
#   '88549439'],
#  ['CedricMBrightMD',
#   'EmilyGuhl',
#   'NationalMedAssn',
#   'DocBanks84',
#   'BHMinfo',
#   'CardioOncology',
#   'StanCVFellows',
#   'drjohnm',
#   'purviparwani',
#   'SCADalliance'],
#  ['jackieaj', 'Aashiq_Kachroo'],
#  ['jackieaj', 'Aashiq_Kachroo'],
#  ['jackieaj', 'Aashiq_Kachroo'],
#  ['jackieaj', 'Troy_McD_UBC'],
#  ['jackieaj', 'Aashiq_Kachroo'],
#  ['jackieaj', 'Aashiq_Kachroo'],
#  ['jackieaj', 'Troy_McD_UBC'],
#  ['jackieaj', 'Aashiq_Kachroo'],
#  ['jackieaj', 'Troy_McD_UBC'],
#  ['jackieaj', 'Aashiq_Kachroo'],
#  ['mdaymon00', 'AOC', 'xanintreb'],
#  ['mdaymon00', 'AOC', 'nurseyERnurse4', 'CallingBSonU', 'Mom2Ian03'],
#  ['mdaymon00', 'AOC', 'PersnicketyRph'],
#  ['mdaymon00', 'AOC', 'Thelyd995'],
#  ['mdaymon00', 'AOC', 'SimpleManMD'],
#  ['mdaymon00', 'AOC', 'SimpleManMD'],
#  ['mdaymon00',
#   'AOC',
#   'anyotherkind',
#   'MsPackyetti',
#   'The_OrthoGod',
#   'Kaimandante',
#   'thatonethingy'],
#  ['mdaymon00', 'AOC', 'pA3on', 'carterforva', 'criener'],
#  ['mdaymon00', 'AOC', 'knittycat1'],
#  ['mdaymon00', 'AOC', 'wade_snowden'],
#  ['josephflaherty', 'varma_ashwin97'],
#  ['josephflaherty', 'varma_ashwin97'],
#  ['josephflaherty', 'varma_ashwin97'],
#  ['josephflaherty', 'varma_ashwin97'],
#  ['josephflaherty', 'varma_ashwin97'],
#  ['josephflaherty', 'varma_ashwin97'],
#  ['josephflaherty', 'varma_ashwin97'],
#  ['josephflaherty', 'varma_ashwin97'],
#  ['josephflaherty', 'varma_ashwin97'],
#  ['josephflaherty', 'varma_ashwin97'],
#  ['AmirLotfi9'],
#  ['AmirLotfi9'],
#  ['AmirLotfi9'],
#  ['AmirLotfi9'],
#  ['AmirLotfi9'],
#  ['AmirLotfi9'],
#  ['AmirLotfi9'],
#  ['AmirLotfi9'],
#  ['AmirLotfi9'],
#  ['AmirLotfi9'],
#  ['RobertKennedyJr',
#   'drcateshanahan',
#   'theJeremyVine',
#   'michaelwoodhci',
#   'I_mitochondria',
#   'KetoDocCLT',
#   'DaleWil39870290'],
#  ['RobertKennedyJr',
#   'allwarriormen',
#   'drcateshanahan',
#   'samiinkinen',
#   'DrSeanOMara',
#   'SBakerMD',
#   'realDonaldTrump',
#   'kksheld',
#   'drbarrymarks',
#   'lbt3um'],
#  ['RobertKennedyJr',
#   'drcateshanahan',
#   'SethDillon',
#   'DrSeanOMara',
#   'samiinkinen',
#   'moreyraortho',
#   'AAOS1',
#   'CarnivoreMD',
#   'BiggestComeback',
#   'ColleenHuberNMD'],
#  ['RobertKennedyJr',
#   'allwarriormen',
#   'bigfatsurprise',
#   'CarnivoreMD',
#   'BrianLenzkes',
#   'DrSeanOMara',
#   'drandyphung',
#   'RobertLustigMD',
#   'BrexitAlex',
#   'KetoDocCLT'],
#  ['RobertKennedyJr',
#   'CarnivoreMD',
#   'NancyAB252',
#   'davidludwigmd',
#   'DrEenfeldt',
#   'bschermd',
#   'DoctorTro',
#   'DrDerek1015',
#   'lskeptic2',
#   'SBakerMD'],
#  ['RobertKennedyJr',
#   'drcateshanahan',
#   'moreyraortho',
#   'AAOS1',
#   'DrSeanOMara',
#   'realDonaldTrump',
#   'DawnMarie17078',
#   'mitchellvii',
#   'MiltonWolfMD',
#   'DrJ3ckyll'],
#  ['RobertKennedyJr',
#   'drcateshanahan',
#   'moreyraortho',
#   'Harvard',
#   'KetoDocCLT',
#   'SethDillon',
#   'DrSeanOMara',
#   'drandyphung',
#   'ascarbs',
#   'DrNadolsky'],
#  ['RobertKennedyJr',
#   'CarnivoreMD',
#   'susannareid100',
#   'RobertLustigMD',
#   'basiliskgpt6942',
#   'DrRobDavidson',
#   'Kaimandante',
#   'SavSmith04'],
#  ['RobertKennedyJr',
#   'allwarriormen',
#   'DrAseemMalhotra',
#   'TonyBurnetti',
#   'DrRobDavidson',
#   'ChrisCuomo',
#   'visionxcl',
#   'wolfblitzer',
#   'CDCDirector',
#   'NeilFlochMD'],
#  ['RobertKennedyJr',
#   'allwarriormen',
#   'susannareid100',
#   'drcateshanahan',
#   'KetoDocCLT',
#   'RobertLustigMD',
#   'jdelugach',
#   'CarnivoreMD',
#   'davidludwigmd',
#   'DrRamonIssa'],
#  ['MSUPedsPulm'],
#  ['MSUPedsPulm'],
#  ['MSUPedsPulm'],
#  ['MSUPedsPulm'],
#  ['MSUPedsPulm'],
#  ['MSUPedsPulm'],
#  ['MSUPedsPulm'],
#  ['MSUPedsPulm'],
#  ['MSUPedsPulm'],
#  ['MSUPedsPulm'],
#  ['EmilyVanDuyne',
#   'briebriejoy',
#   'doctoreebs',
#   'ninaturner',
#   'MyScarletFelony',
#   'SpeakerPelosi',
#   'Chloecat254',
#   'HouseDemocrats'],
#  ['EmilyVanDuyne', 'diabetesalish'],
#  ['EmilyVanDuyne',
#   'ninaturner',
#   'SpicySultyDoggy',
#   'briebriejoy',
#   'tylasade',
#   'AyannaPressley',
#   'JessicaRN1995'],
#  ['EmilyVanDuyne',
#   'ninaturner',
#   'doctoreebs',
#   'briebriejoy',
#   'gangsterhealth',
#   'RealArmi',
#   'DrLearnALot',
#   'DanielHofheinz'],
#  ['EmilyVanDuyne', 'briebriejoy', 'MaxFromKendall', 'sarabeth2021'],
#  ['EmilyVanDuyne',
#   'ninaturner',
#   'shift_in2_turbo',
#   'IlhanMN',
#   'whiteroz51',
#   'fenderjessbass'],
#  ['EmilyVanDuyne',
#   'briebriejoy',
#   'doctoreebs',
#   'ninaturner',
#   'tylasade',
#   'AyannaPressley',
#   'LukasGaffneyMD'],
#  ['EmilyVanDuyne',
#   'ninaturner',
#   'shift_in2_turbo',
#   'BenjaminPDixon',
#   'r8dr4lfe75',
#   'AOC',
#   'bilbobaggins40'],
#  ['EmilyVanDuyne', 'ninaturner', 'tylasade', 'IcebergAk', '_shykiaa'],
#  ['EmilyVanDuyne', 'diabetesalish'],
#  ['RyanLundergan', 'AyannaPressley', 'Justice_Nyet'],
#  ['RyanLundergan',
#   'AyannaPressley',
#   'DrMarthaGulati',
#   'chadialraies',
#   'radcliffeCARDIO',
#   'atunuguntla1',
#   'munes_fares',
#   'JyothsnaMD',
#   'drstaceyrosen',
#   'netta_doc'],
#  ['RyanLundergan', 'AyannaPressley', 'ORDiane'],
#  ['RyanLundergan', 'AyannaPressley', 'THEECAPRlCORN'],
#  ['RyanLundergan', 'AyannaPressley', 'IndieBombDotCom', 'SkyviewThompson'],
#  ['RyanLundergan', 'AyannaPressley', 'AngelaDillon'],
#  ['RyanLundergan',
#   'AyannaPressley',
#   'RobinCogan',
#   'statnews',
#   'KentBottles',
#   'EricTopol',
#   'maraantonoff',
#   'TomVargheseJr',
#   'anjalibhagramd',
#   'whitemd'],
#  ['RyanLundergan', 'AyannaPressley', 'UnruhlySarah'],
#  ['RyanLundergan',
#   'AyannaPressley',
#   'kevin_cracknell',
#   'Newsweek',
#   'CatActExpert',
#   'ScottAdamsSays',
#   'QQBeautifulDove',
#   'gtfinchy'],
#  ['RyanLundergan', 'AyannaPressley', 'SubversiveMD'],
#  ['Teleneurology',
#   'AlsaiedTarek',
#   'SamWittekind',
#   'DrJenniferCo_Vu',
#   'MVMadhavanMD',
#   'nataliebello9',
#   'ivorbenjamin2',
#   'rooshaparikh',
#   'dbelardomd',
#   'MahazarinG'],
#  ['Teleneurology',
#   'ggvela',
#   'DLBHATTMD',
#   'drmalissawood',
#   'khurramn1',
#   'mirvatalasnag',
#   'virani_md',
#   'ajaykirtane',
#   'DVervoort94',
#   'ValleAlfonso'],
#  ['Teleneurology',
#   'FredWuMD',
#   'DrDePasquale',
#   'HeartBobH',
#   'PennMedNews',
#   'AlliBigeh',
#   'ersied727',
#   'DrKLindley',
#   'CMichaelGibson',
#   'KoushikReddyMD'],
#  ['Teleneurology',
#   'mjnickolaus',
#   'iamritu',
#   'datsunian',
#   'Circulation',
#   'DBelardoMD',
#   'gmacscotland',
#   'ggvela',
#   'a_l_bailey',
#   'mirvatalasnag'],
#  ['Teleneurology',
#   'drjohnm',
#   'bnallamo',
#   'DrRosanneRouf',
#   'NirUrielMD',
#   'abrahahailu',
#   'aairaqiSCAI',
#   'ElaineWanMD',
#   'JMongeMD',
#   'DrHenryTran'],
#  ['Teleneurology',
#   'DrMarthaGulati',
#   'JeremyAsnesMD',
#   'FredWuMD',
#   'DrJRums',
#   'AHAScience',
#   'yaleHFdoc',
#   'andywoods27',
#   'DrClaudiusMahr',
#   'AHA_Dallas'],
#  ['Teleneurology',
#   'AmiBhattMD',
#   'BellevueHosp',
#   'MelindaDavisMD',
#   'NanditaScott',
#   'yaqoub_lina',
#   'ESCardioNews',
#   'IvoMd',
#   'sbrugaletta',
#   'avolgman'],
#  ['Teleneurology',
#   'mjnickolaus',
#   'RasuShrestha',
#   'JagSinghMD',
#   'MayoClinicCV',
#   'skilicmd',
#   'avolgman',
#   'ivorbenjamin2',
#   'virani_md',
#   'DLBHATTMD'],
#  ['Teleneurology',
#   'DrQuinnCapers4',
#   'anna_bortnick',
#   'drelisabradley',
#   'ElaineWanMD',
#   'Pooh_Velagapudi',
#   'GoRedForWomen',
#   'Fentanes_MD',
#   'daniel_forsha',
#   'TCTMD_Yael'],
#  ['Teleneurology',
#   'cardioPCImom',
#   'drundrwd',
#   'NitiCardio',
#   'NanditaScott',
#   'aakriti_15',
#   'shwinner',
#   'rs_gc',
#   'drelisabradley',
#   'mmamas1973'],
#  ['lastport'],
#  ['lastport'],
#  ['lastport'],
#  ['lastport'],
#  ['lastport'],
#  ['lastport'],
#  ['lastport'],
#  ['lastport'],
#  ['lastport'],
#  ['lastport'],
#  ['samgandy', 'karchlab', 'shannjiang2016'],
#  ['samgandy', 'karchlab', 'shannjiang2016'],
#  ['samgandy', 'karchlab', 'shannjiang2016'],
#  ['samgandy', 'karchlab', 'shannjiang2016'],
#  ['samgandy', 'karchlab', 'shannjiang2016'],
#  ['samgandy', 'karchlab', 'shannjiang2016'],
#  ['samgandy', 'karchlab', 'shannjiang2016'],
#  ['samgandy', 'karchlab', 'shannjiang2016'],
#  ['samgandy', 'karchlab', 'shannjiang2016'],
#  ['samgandy', 'karchlab', 'shannjiang2016'],
#  ['Ryder1Samoan', 'kellyclose', 'StephenSType1'],
#  ['Ryder1Samoan',
#   'kellyclose',
#   'PhRMA',
#   'YatDeb',
#   'GarwoodStevens',
#   'janetwooten1',
#   'cloudess',
#   'arjun42',
#   'lollydaggle',
#   'DrJenShineDyer'],
#  ['Ryder1Samoan',
#   'kellyclose',
#   'diaTribeNews',
#   'mikesbkelly',
#   'DiabetesMine',
#   'HopeWarshaw',
#   'MedscapeCME'],
#  ['Ryder1Samoan', 'kellyclose', 'lollydaggle', 'DrLearnALot', 'RobbyMook'],
#  ['Ryder1Samoan', 'kellyclose', 'PhRMA', 'YatDeb', 'steveubl'],
#  ['Ryder1Samoan',
#   'kellyclose',
#   'LillyPad',
#   'janetwooten1',
#   'SecAzar',
#   'NeilFlochMD',
#   'SteveFDA',
#   'DrArgyle',
#   'kcferdmd',
#   'DrJayMohan'],
#  ['Ryder1Samoan', 'kellyclose', 'IsletTx'],
#  ['Ryder1Samoan',
#   'kellyclose',
#   'LillyPad',
#   'simmons_leighmd',
#   'novonordiskus',
#   'arjun42',
#   'DCinsulin4all',
#   'ginger_annEdD'],
#  ['Ryder1Samoan',
#   'kellyclose',
#   'PBS',
#   'KOBPharmD',
#   'novonordiskus',
#   'jaydotpdf',
#   'KORcombat'],
#  ['Ryder1Samoan',
#   'kellyclose',
#   'insulinth0t',
#   'arjun42',
#   'DCinsulin4all',
#   'ginger_annEdD',
#   'LillyPad',
#   'PaolilloChrissy',
#   'Sanofi',
#   'InsulinpumpM'],
#  ['kiranmahmood516',
#   'EstefaniaOS',
#   'MahazarinG',
#   'pharmacists',
#   'aakriti_15',
#   'projo',
#   'DrKLindley',
#   'JonathanDavisHF',
#   'tonkhueMdPhd',
#   'AminYehyaMD'],
#  ['kiranmahmood516',
#   'EstefaniaOS',
#   'Vilavaite',
#   'jesse8850',
#   'thaiscoutinhoCV',
#   'medicalaxioms',
#   'CaliforniaACC',
#   'RBP0612',
#   'chiarabd',
#   'dr_adeebq'],
#  ['kiranmahmood516',
#   'dranulala',
#   'ColumbiaMed',
#   'SharonneHayes',
#   'drdavemd',
#   'ajaysmd',
#   'SCADalliance',
#   'dr_adeebq',
#   'maracarolinemd',
#   'OKhaliqueMD'],
#  ['kiranmahmood516',
#   'dranulala',
#   'Chintanpmd',
#   'a_l_bailey',
#   'mmerschel',
#   'medicalaxioms',
#   'TCTMD',
#   'ajaysmd',
#   'CMichaelGibson',
#   'KTamirisaMD'],
#  ['kiranmahmood516',
#   'SumeetMitter',
#   'Jcontreras75',
#   'EstefaniaOS',
#   'PushpaShivaram',
#   'DLSM_MD',
#   'DrJenniferCo_Vu',
#   'HeartBobH',
#   'OKhaliqueMD',
#   'HeartNews'],
#  ['kiranmahmood516',
#   'EstefaniaOS',
#   'escardio',
#   'AnnGageMD',
#   'DrToniyaSingh',
#   'RasuShrestha',
#   'DrJayMohan',
#   'ACCOregon',
#   'BrettSperryMD',
#   'MasriAhmadMD'],
#  ['kiranmahmood516',
#   'SumeetMitter',
#   'DonnaMancini11',
#   'EstefaniaOS',
#   'jeffreygeske',
#   'gina_lundberg',
#   'MonSangh',
#   'venkmurthy',
#   'Cardiology',
#   'a_l_bailey'],
#  ['kiranmahmood516',
#   'EstefaniaOS',
#   'SCADalliance',
#   'OKhaliqueMD',
#   'alessia_gimelli',
#   'sandylewis',
#   'medicalaxioms',
#   'FredWuMD',
#   'CardioSmart',
#   'drladyheart'],
#  ['kiranmahmood516',
#   'dranulala',
#   'NanditaScott',
#   'aakriti_15',
#   'MinnowWalsh',
#   'HeartOTXHeartMD',
#   'novonordiskus',
#   'AllisonRBond',
#   'SamStellpflug',
#   'J_Corky'],
#  ['kiranmahmood516',
#   'dranulala',
#   'GradyHealth',
#   'avolgman',
#   'nataliebello9',
#   'sandylewis',
#   'rahatheart1',
#   'UjjwalRastogiMD',
#   'Vetrovec',
#   'HFnursemaghee'],
#  ['DrJesseMorse', 'FantasyFatguys'],
#  ['DrJesseMorse', 'FantasyFatguys'],
#  ['DrJesseMorse', 'FantasyFatguys'],
#  ['DrJesseMorse', 'FantasyFatguys'],
#  ['DrJesseMorse', 'FantasyFatguys'],
#  ['DrJesseMorse', 'FantasyFatguys'],
#  ['DrJesseMorse', 'FantasyFatguys'],
#  ['DrJesseMorse', 'FantasyFatguys'],
#  ['DrJesseMorse', 'FantasyFatguys'],
#  ['DrJesseMorse', 'FantasyFatguys'],
#  ['Alarm_Fatigue',
#   'srrezaie',
#   'virenkaul',
#   'DrAmirKaki',
#   'escardio',
#   'EugeniaGianos',
#   'ktaubert',
#   'drladyheart',
#   'NMHheartdoc',
#   'a_l_bailey'],
#  ['Alarm_Fatigue',
#   'virenkaul',
#   'srrezaie',
#   'Ags_win',
#   'MelHerbert',
#   'emedtox'],
#  ['Alarm_Fatigue',
#   'srrezaie',
#   'GilbertPharmD',
#   'rxpalette',
#   'lilhwn2',
#   'JACCPJournal'],
#  ['Alarm_Fatigue',
#   'virenkaul',
#   'DrAmirKaki',
#   'MKIttlesonMD',
#   'AnkurKalraMD',
#   'drdavemd',
#   'HafizaKMD',
#   'aayshacader',
#   'ikutkutMD',
#   'purviparwani'],
#  ['Alarm_Fatigue',
#   'virenkaul',
#   'Babar_Basir',
#   'TTelila',
#   'DrToniyaSingh',
#   'Teleneurology',
#   'gina_lundberg',
#   'uche_blackstock',
#   'KaliyadanMD',
#   'vbeadmd'],
#  ['Alarm_Fatigue',
#   'virenkaul',
#   'DrJayMohan',
#   'MichiganACC',
#   'virani_md',
#   'DrKLindley',
#   'NanetteWenger',
#   'DrLaxmiMehta',
#   'HighSTEACS',
#   'MasriAhmadMD'],
#  ['Alarm_Fatigue',
#   'virenkaul',
#   'DrAmirKaki',
#   'mmamas1973',
#   'BrettSperryMD',
#   'DrPRao',
#   'DrJayMohan',
#   'MassGeneralNews',
#   'NutritionMadeS3',
#   'nyphospital'],
#  ['Alarm_Fatigue',
#   'virenkaul',
#   'a_l_bailey',
#   'ajaykirtane',
#   'HeartBobH',
#   'figshare',
#   'mmillermd1',
#   'Medtelligence',
#   'DLBHATTMD',
#   'DavidMayMD'],
#  ['Alarm_Fatigue',
#   'srrezaie',
#   'ICUapothecary',
#   'rxpalette',
#   'accpcritprn',
#   'SICUPharmD',
#   'JAMANetwork',
#   'SCCMPresident',
#   'catnswamp'],
#  ['Alarm_Fatigue',
#   'virenkaul',
#   'coffeeNCalibers',
#   'emily_fri',
#   'joshpauljolly',
#   'DrMStiegler',
#   'GallodeMoraesMD',
#   'Dinahlew',
#   'abkim414',
#   'HaleyFeazelOrr'],
#  ['JMongeMD',
#   'ddefariayeh',
#   'WMUR9',
#   'TCTMD_Yael',
#   'lesleejshaw',
#   'DrJayMohan',
#   'nyugrossman',
#   'DBelardoMD',
#   'mpsotka',
#   'AHA_Dallas'],
#  ['JMongeMD',
#   'DrHenryTran',
#   'KBerlacher',
#   'erichorlick',
#   'NirUrielMD',
#   'CellCellPress',
#   'purviparwani',
#   'hopkinsheart',
#   'MelindaDavisMD',
#   'ErinMichos'],
#  ['JMongeMD',
#   'erichorlick',
#   'DrJCheungEP',
#   'SimranSinghMD',
#   'YAdejumoMD',
#   'PCIsurgeon',
#   'SharonneHayes',
#   'basmahsaf',
#   'Nidhi_Madan9',
#   'NEJM'],
#  ['JMongeMD',
#   'gabyweissman',
#   'NirUrielMD',
#   'bvantassell',
#   'SamPowellMD',
#   'AbbateAntonio',
#   'pranav_mankad',
#   'VCU_IMRes',
#   'jaideeppatelmd',
#   'AudreyBJernigan'],
#  ['JMongeMD',
#   'ddefariayeh',
#   'mpabrams',
#   'Drroxmehran',
#   'SCADalliance',
#   'ggvela',
#   'CCFcards',
#   'Nishant_ShahMD',
#   'edwardmillermd',
#   'AkhmetzhanG'],
#  ['JMongeMD',
#   'SimranSinghMD',
#   'theheartdoc',
#   'TCTMD',
#   'FaheemYounus',
#   'ZanmiLasanteht',
#   'DLBHATTMD',
#   'DrDarshanDoshi',
#   'DrSheilaSahni',
#   'DrJayMohan'],
#  ['JMongeMD',
#   'cardiacpolymath',
#   'ddefariayeh',
#   'ElaineWanMD',
#   'NicoleCruzMD',
#   'KBerlacher',
#   'MGLevin',
#   'NirUrielMD',
#   'gtsayer',
#   'HamidGhanbariMD'],
#  ['JMongeMD',
#   'ddefariayeh',
#   'athenapoppas',
#   'HeartBobH',
#   'TCTMD_Yael',
#   'AMWADoctors',
#   'AmiBhattMD',
#   'NirUrielMD',
#   'ESCardioNews',
#   'skathire'],
#  ['JMongeMD',
#   'DrJCheungEP',
#   'BrighamResearch',
#   'cpcannon',
#   'CircAHA',
#   'DougDrachmanMD',
#   'dramitkhera',
#   'DrJenniferCo_Vu',
#   'ShashankSinhaMD',
#   'AndrewJSauer'],
#  ['JMongeMD',
#   'erichorlick',
#   'KBerlacher',
#   'PennMedNews',
#   'arwaxler',
#   'sandylewis',
#   'BcsPresident',
#   'GuruKowlgi',
#   'NancyatHeart',
#   'purviparwani'],
#  ['DrDapo',
#   'LUcardsfellows',
#   'TheFunshul',
#   'ZanmiLasanteht',
#   'KoushikReddyMD',
#   'AHAScience',
#   'TresaMcNealMD',
#   'DrJayMohan',
#   'CardioOncology',
#   'DorbalaSharmila'],
#  ['DrDapo',
#   'sahilparikhmd',
#   'AnkurKalraMD',
#   'INC_CathLab',
#   'atunuguntla1',
#   'SmadarKort',
#   'EmilyGuhl',
#   'HealioCME',
#   'DrAdaStefanescu',
#   'MasriAhmadMD'],
#  ['DrDapo',
#   'RadialFirstBot',
#   'FaheemYounus',
#   'NirUrielMD',
#   'datsunian',
#   'SEMES_',
#   'DrJayMohan',
#   'DocSavageTJU',
#   'DaktariJay',
#   'fischman_david'],
#  ['DrDapo',
#   'AHA_Dallas',
#   'shwinner',
#   'IAmDrIbrahim',
#   'skilicmd',
#   'AmberJohnsonMD',
#   'PittCardiology',
#   'AkhilNarangMD',
#   'neelchokshi',
#   'RBP0612'],
#  ['DrDapo',
#   'edwardmillermd',
#   'JenHoCardiology',
#   'NMCardioVasc',
#   'aklfahed',
#   'MGHHeartHealth',
#   'skilicmd',
#   'EmoryMedicine',
#   'KTamirisaMD',
#   'safinmc'],
#  ['DrDapo',
#   'ElliottMillerMD',
#   'ShelleyWood2',
#   'Nidhi_Madan9',
#   'AmiBhattMD',
#   'munes_fares',
#   'HeartBobH',
#   'DrTGupta',
#   'fitmslax',
#   'laurelfick'],
#  ['DrDapo',
#   'JenHoCardiology',
#   'ElliottMillerMD',
#   'iamritu',
#   'avolgman',
#   'NKasparian',
#   'AkhilNarangMD',
#   'emilyswlau',
#   'HimadKhattak',
#   'ShadyHenienMD'],
#  ['DrDapo',
#   'heartdocandcrew',
#   'yaqoub_lina',
#   'ajaykirtane',
#   'ycommodore',
#   'ACHA_Heart',
#   'AlsaiedTarek',
#   'mikebiselli',
#   'DrJayMohan',
#   'ShelbyKuttyMD'],
#  ['DrDapo',
#   'sabeedak1',
#   'ozlembilen2',
#   'pduncan54',
#   'drjeffle',
#   'ccardyDNP',
#   'DrTGupta',
#   'drmalissawood',
#   'ekgpdx',
#   'VietHeartPA'],
#  ['DrDapo',
#   'SVRaoMD',
#   'DrJMarine',
#   'KTamirisaMD',
#   'ASE360',
#   'drmaggarwal',
#   'hpatel824',
#   'EugeniaGianos',
#   'projo',
#   'nataliebello9'],
#  ['DrJenShineDyer',
#   'slooterman',
#   'analgesicsleep',
#   'AyannaPressley',
#   'aL_bahhh'],
#  ['DrJenShineDyer', 'lollydaggle', 'McBlondeLand'],
#  ['DrJenShineDyer', 'slooterman', 'analgesicsleep', 'AOC', 'adventurephile'],
#  ['DrJenShineDyer', 'lollydaggle', 'McBlondeLand'],
#  ['DrJenShineDyer',
#   'slooterman',
#   'analgesicsleep',
#   'AyannaPressley',
#   'HGhomefordogs',
#   'AOC',
#   '1RadicalNurse',
#   'eugenegu',
#   'Temichno',
#   'QasimRashid'],
#  ['DrJenShineDyer',
#   'slooterman',
#   'analgesicsleep',
#   'Kaimandante',
#   'RealMikeHuffman',
#   'aolvera04'],
#  ['DrJenShineDyer',
#   'slooterman',
#   'analgesicsleep',
#   'AyannaPressley',
#   'byrnes_lori',
#   'ccunningham821'],
#  ['DrJenShineDyer', 'lollydaggle', 'DrLearnALot', 'Bakari_Sellers'],
#  ['DrJenShineDyer',
#   'slooterman',
#   'analgesicsleep',
#   'AyannaPressley',
#   'KHGlasgow'],
#  ['DrJenShineDyer',
#   'lollydaggle',
#   'arjun42',
#   'Kidfears99',
#   'LoriRuder',
#   'novonordiskus',
#   'PrimeSurgicare',
#   'FiercePharma'],
#  ['DietHeartNews', 'Familymeddawg'],
#  ['DietHeartNews',
#   'DrNadolsky',
#   'drkenber',
#   'drandyphung',
#   'TomClay44',
#   'DrSeanOMara',
#   'Bobbert69572732',
#   'KetoDocCLT',
#   'nursedebi'],
#  ['DietHeartNews', 'Familymeddawg'],
#  ['DietHeartNews',
#   'PaulSpottswood',
#   'ketocoachvic',
#   'DrNadolsky',
#   'https',
#   'Drlipid',
#   'MeralKayikciog1'],
#  ['DietHeartNews', 'Familymeddawg'],
#  ['DietHeartNews',
#   'KetoDocCLT',
#   'nadia_pateguana',
#   'RobertLustigMD',
#   'American_Heart',
#   'SpencerCarter55',
#   'sandeepdasmd',
#   'UUcvsl',
#   'leenhapong',
#   'JJRyanMD'],
#  ['DietHeartNews', 'Familymeddawg'],
#  ['DietHeartNews',
#   'drfmd_keto',
#   'bigfatsurprise',
#   'NirUrielMD',
#   'cardioPCImom',
#   'DrOstfeld',
#   'MasriAhmadMD',
#   'NitiCardio',
#   'kejoynt',
#   'DLBHATTMD'],
#  ['DietHeartNews', 'PaulSpottswood', 'KetoDocCLT', 'gotinsulin'],
#  ['DietHeartNews',
#   'KetoDocCLT',
#   'CarnivoreMD',
#   'cadiulus',
#   'DrDave01',
#   'JAmCollSurg',
#   'TomVargheseJr',
#   'MayoClinicCV',
#   'Nidhi_Madan9',
#   'krishnapatel888'],
#  ['MatthewBaehr13',
#   'DrPhil',
#   'Dyane357',
#   'Acyn',
#   'mdbbrooks',
#   'MontyBoa99',
#   'dredh08'],
#  ['MatthewBaehr13',
#   'DrPhil',
#   'Reza5150',
#   'Acyn',
#   'byrnes_lori',
#   'AyannaPressley',
#   'Doloresgalla1'],
#  ['MatthewBaehr13', 'FoxNews', 'DarshanaN'],
#  ['MatthewBaehr13', 'DrPhil', 'JoeIra4', 'Acyn', 'BHallBabyDoc'],
#  ['MatthewBaehr13',
#   'DrPhil',
#   'Dyane357',
#   'HarrenGWarding',
#   'TheRebelPatient',
#   'EwingT_PhD'],
#  ['MatthewBaehr13', 'FoxNews', 'TheTweetinChris', 'BadFoxGraphics'],
#  ['MatthewBaehr13',
#   'DrPhil',
#   'JoeIra4',
#   'HarrenGWarding',
#   'Reza5150',
#   'Acyn',
#   'byrnes_lori',
#   'AyannaPressley',
#   'EbonyJadeHilton',
#   'DrRayMD'],
#  ['MatthewBaehr13',
#   'FoxNews',
#   'barbarabwatkins',
#   'MSNBC',
#   'ChristianDem47',
#   'chrislhayes',
#   'SunnyInTheKeys'],
#  ['MatthewBaehr13', 'FoxNews', 'AirRescueMD', 'Goldstatetimes'],
#  ['MatthewBaehr13', 'DrPhil', 'aliceclearman', 'ValueDecency'],
#  ['AbbottCardio',
#   'madisonbpowell',
#   'HRSonline',
#   'RyanTedfordMD',
#   'PradTummala',
#   'ACCinTouch',
#   'AVogel_DO',
#   'EmergencyDocs',
#   'purviparwani',
#   'MacalusoJoseph'],
#  ['AbbottCardio', 'norman_yu'],
#  ['AbbottCardio', 'SteveOnWeck'],
#  ['AbbottCardio',
#   'madisonbpowell',
#   'HRSonline',
#   'PaulVarosy',
#   'DeptVetAffairs',
#   'BinitaShahMD',
#   'CDCgov',
#   'jennlewey',
#   'HeartNews',
#   'MRMehraMD'],
#  ['AbbottCardio', 'norman_yu'],
#  ['AbbottCardio', 'norman_yu'],
#  ['AbbottCardio', 'norman_yu'],
#  ['AbbottCardio', 'SteveOnWeck'],
#  ['AbbottCardio',
#   'madisonbpowell',
#   'HRSonline',
#   'ethanjweiss',
#   'EricTopol',
#   'cpeedell',
#   'hjluks',
#   'drdavidpalma',
#   'DrMarthaGulati',
#   'CardiologyYoung'],
#  ['AbbottCardio',
#   'madisonbpowell',
#   'HRSonline',
#   'DUSA100',
#   'AHA_Research',
#   'KTamirisaMD',
#   'USEmbassySerbia',
#   'DocStrom',
#   'RafathUllah20',
#   'DanielJohnsrud'],
#  ['AlexBerenson', 'aniketa27', 'TheRealRobbyT'],
#  ['AlexBerenson',
#   'MigraineBook',
#   'DrAseemMalhotra',
#   'CarnivoreMD',
#   'DiscoStew66',
#   'carblessness',
#   'LDLskeptic2',
#   'drandyphung',
#   'DrNadolsky',
#   'MeralKayikciog1'],
#  ['AlexBerenson', 'FuriosaDr', 'stephenmatlock'],
#  ['AlexBerenson', 'aniketa27', 'lynnhailey1'],
#  ['AlexBerenson', 'FuriosaDr', 'ou_country'],
#  ['AlexBerenson', 'FuriosaDr', 'ou_country'],
#  ['AlexBerenson',
#   'Cmichaelmd',
#   'CDCgov',
#   'KoushikReddyMD',
#   'SSharmacardio',
#   'LauraFlowersE',
#   'BethFratesMD',
#   'HanCardiomd',
#   'DavidLBrownMD',
#   'chiarabd'],
#  ['AlexBerenson', 'FuriosaDr', 'stephenmatlock'],
#  ['AlexBerenson', 'aniketa27', 'TheRealRobbyT'],
#  ['AlexBerenson',
#   'MigraineBook',
#   'DrAseemMalhotra',
#   'lewistlc',
#   '88549439',
#   'DrFrankLipman',
#   'fischman_david',
#   'skathire',
#   'kd_nephro',
#   'KevinBSneed'],
#  ['ECGTalk', 'amerelman', 'NationalHeart'],
#  ['ECGTalk', 'amerelman', 'NationalHeart'],
#  ['ECGTalk', 'amerelman', 'NationalHeart'],
#  ['ECGTalk',
#   'amerelman',
#   'fazalabul',
#   'anastaqa',
#   'LubertMD',
#   'laurenranard',
#   'DLBHATTMD',
#   'pduncan54',
#   'SVRaoMD',
#   'DBelardoMD'],
#  ['ECGTalk', 'amerelman', 'NationalHeart'],
#  ['ECGTalk', 'amerelman', 'NationalHeart'],
#  ['ECGTalk',
#   'amerelman',
#   'fazalabul',
#   'jpkca',
#   'Cardiology',
#   'CardioOncology',
#   'AChoiHeart',
#   'AmberJohnsonMD',
#   'MayoAmyloid',
#   'SaulJSilver'],
#  ['ECGTalk',
#   'amerelman',
#   'airwaycam',
#   'Country_fiedMD',
#   'jessica_bunin',
#   'emily_fri',
#   'robertomlang',
#   'MukarramOsama',
#   'AmitRPatelMD',
#   'Allan1246'],
#  ['ECGTalk',
#   'amerelman',
#   'fazalabul',
#   'salimhayek',
#   'AtulBaliMD',
#   'kidney_boy',
#   'DocWoc71',
#   'emoryimchiefs',
#   'medpedshosp',
#   'Armstrws'],
#  ['ECGTalk', 'amerelman', 'airwaycam', 'NickMD1980'],
#  ['MARspidermonkey',
#   'AyannaPressley',
#   'EbonyJadeHilton',
#   'DrRayMD',
#   'UC_CCTST',
#   'silvishah',
#   'UC_CoMResearch'],
#  ['MARspidermonkey', 'AyannaPressley', 'shakespearelovr'],
#  ['MARspidermonkey', 'AyannaPressley', 'HPatrick_PhD'],
#  ['MARspidermonkey',
#   'DrAshleyEdes',
#   'AyannaPressley',
#   'vfarris27',
#   'MsPackyetti',
#   'bibbleshanks'],
#  ['MARspidermonkey',
#   'AyannaPressley',
#   'presidentextra',
#   'IlhanMN',
#   'LoriRuder',
#   'JDRF',
#   'OshKayKay',
#   'MysterySolvent',
#   'UnorthodoxPop'],
#  ['MARspidermonkey',
#   'AyannaPressley',
#   'HicksShana',
#   'DrRobDavidson',
#   'American_Heart',
#   'nirvidahiya',
#   'hvanspall',
#   'yaqoub_lina',
#   'biljana_parapid',
#   'yourheartdoc1'],
#  ['MARspidermonkey',
#   'DrAshleyEdes',
#   'AyannaPressley',
#   'jamaicanjune2',
#   'BillKristol',
#   'tim_horrigan'],
#  ['MARspidermonkey',
#   'DrAshleyEdes',
#   'AyannaPressley',
#   'BeeBabiCakes',
#   'IcebergAk',
#   'httpt0ny'],
#  ['MARspidermonkey', 'AyannaPressley', 'boogie_mans'],
#  ['MARspidermonkey',
#   'AyannaPressley',
#   'rizwanafl',
#   'ACOG',
#   'CatchTheBaby',
#   'GilmerHealthLaw',
#   'yayayarndiva',
#   'BlackJesuscom',
#   'Laurie_Garrett',
#   'JohnsHopkinsSPH'],
#  ['MountSinaiHeart',
#   'dranulala',
#   'athenapoppas',
#   'arghavan_salles',
#   'UFJaxDeanHaley',
#   'DocElovitz',
#   'anna_bortnick',
#   'aakriti_15',
#   'JGrapsa',
#   'DrMarthaGulati'],
#  ['MountSinaiHeart',
#   'DSadlerMD',
#   'Dr_Mike_Fradley',
#   'TomasNeilan',
#   'DrPascalMeier',
#   'skathire',
#   'DrRyanPDaly',
#   'BenLaBolt',
#   'LizUmberfield'],
#  ['MountSinaiHeart',
#   'Dr_Mike_Fradley',
#   'CedarsSinai',
#   'Rongtian2',
#   'ICVS_UoB',
#   'EbruErbayLab',
#   'Pagliarini_Lab',
#   'DrRGJonesLab',
#   'phillipwhite14',
#   'rob_mcgarrah'],
#  ['MountSinaiHeart',
#   'Dr_Mike_Fradley',
#   'CedarsSinai',
#   'CardioOncology',
#   'sanjayvdesai',
#   'AmberJohnsonMD',
#   'American_Heart',
#   'IowaWIC',
#   'aayshacader',
#   'DrJayMohan'],
#  ['MountSinaiHeart',
#   'CardioOncology',
#   'JGrapsa',
#   'AnkurKalraMD',
#   'sahilparikhmd',
#   'Nidhi_Madan9',
#   'AtriumHealth',
#   'nataliebello9',
#   'noshreza',
#   'AndrewJSauer'],
#  ['MountSinaiHeart',
#   'SumeetMitter',
#   'mayabarghash',
#   'EstefaniaOS',
#   'CardioSmart',
#   'SamOJonesMD',
#   'oldracer90',
#   'beaverspharmd',
#   'MelindaDavisMD',
#   'PamelaBMorris'],
#  ['MountSinaiHeart',
#   'EstefaniaOS',
#   'venkmurthy',
#   'vbeadmd',
#   'drmalissawood',
#   'purviparwani',
#   'ABCardio1',
#   'DanielJohnsrud',
#   'PennCardiology',
#   'NitiCardio'],
#  ['MountSinaiHeart',
#   'Dr_Mike_Fradley',
#   'DSadlerMD',
#   'CardiologyToday',
#   'CardioOncology',
#   'sandylewis',
#   'DoctorLatina',
#   'RonBlankstein',
#   'basmahsaf',
#   'jesse8850'],
#  ['MountSinaiHeart',
#   'SumeetMitter',
#   'AditiSinghvi4',
#   'dranulala',
#   'HeartBobH',
#   'Latinx16',
#   'Bravo__MD',
#   'PamChMD',
#   'Drroxmehran',
#   'Dr_BowTie65'],
#  ['MountSinaiHeart',
#   'EstefaniaOS',
#   'dranulala',
#   'Chintanpmd',
#   'Pooh_Velagapudi',
#   'purviparwani',
#   'NMHheartdoc',
#   'leahjohnMD',
#   'MichiganACC',
#   'AmiBhattMD'],
#  ['DarlingDestyni', 'MsPackyetti', 'allenshutup', 'Kaimandante', 'StoryScott'],
#  ['DarlingDestyni', 'IcebergAk', 'princessxjasey'],
#  ['DarlingDestyni', 'IcebergAk', 'dapper_droo'],
#  ['DarlingDestyni', 'IcebergAk', 'mdollasss'],
#  ['DarlingDestyni',
#   'IcebergAk',
#   'presidentextra',
#   'AyannaPressley',
#   'siehk934'],
#  ['DarlingDestyni', 'IcebergAk', 'roxsann_'],
#  ['DarlingDestyni', 'IcebergAk', 'Commandr_nchief'],
#  ['DarlingDestyni',
#   'MsPackyetti',
#   'SophiaRahming1',
#   'Reuters',
#   'JoRunsMD',
#   'HeeShin',
#   'lynney62'],
#  ['DarlingDestyni',
#   'MsPackyetti',
#   'SpoiledMeg_89',
#   'Kaimandante',
#   '___aestheticG',
#   'IcebergAk',
#   'JustHere4Mystry'],
#  ['DarlingDestyni', 'MsPackyetti', 'JordenRevels'],
#  ['nrpate4',
#   'kwoolfmd',
#   'drmkmittal',
#   'TomasNeilan',
#   'DrAmirKaki',
#   'radiologistpage',
#   'gina_lundberg',
#   'JGrapsa',
#   'DrJMieres',
#   'purviparwani'],
#  ['nrpate4',
#   'kwoolfmd',
#   'AllisonRBond',
#   'tinyboo49',
#   'BillKristol',
#   'AmandaMSidesRN1',
#   'MsPackyetti',
#   'mickeyfoon'],
#  ['nrpate4', 'kwoolfmd', 'PGhoshDO', 'amalmattu', 'collinflan'],
#  ['nrpate4',
#   'kwoolfmd',
#   'DrAmirKaki',
#   'bkolskk',
#   'djc795',
#   'crfheart',
#   'DavidLBrownMD',
#   'AkcharAl',
#   'AdnanKhalifMD',
#   'TCTMD'],
#  ['nrpate4',
#   'kwoolfmd',
#   'MassGeneralNews',
#   'DrJRums',
#   'Dr_BowTie65',
#   'ACCmediacenter',
#   'drdanchoi',
#   'drdavemd',
#   'jesse8850',
#   'drelisabradley'],
#  ['nrpate4',
#   'kwoolfmd',
#   'HanCardiomd',
#   'LauraFlowersE',
#   'SSharmacardio',
#   'BethFratesMD',
#   'TheForeverAlpha',
#   'AmVindicated',
#   'mikelizquierdo_',
#   'KoushikReddyMD'],
#  ['nrpate4',
#   'kwoolfmd',
#   'skathire',
#   'AkhmetzhanG',
#   'pduncan54',
#   'novitskiynic',
#   'DougDrachmanMD',
#   'DrJayMohan',
#   'TODAYshow',
#   'GuruKowlgi'],
#  ['nrpate4',
#   'kwoolfmd',
#   'RangaswJ',
#   'edgarvlermamd',
#   'hswapnil',
#   'kidney_boy',
#   'Cardiobro',
#   'DrHaniMahmoud',
#   'salimhayek',
#   'ACCinTouch'],
#  ['nrpate4',
#   'kwoolfmd',
#   'ShelleyZieroth',
#   'DrTGupta',
#   'geoffrey_rubin',
#   'KTamirisaMD',
#   'ChrisDefilippi',
#   'drstaceyrosen',
#   'Bhuwania12',
#   'purviparwani'],
#  ['nrpate4', 'kwoolfmd', 'J_Corky', 'SamStellpflug', 'nephrotox'],
#  ['purviparwani', 'Rover829', 'katz_mum', 'junghpak1', 'DaveShullman'],
#  ['purviparwani',
#   'ACCMass',
#   'pnatarajanmd',
#   'JimJohnsonSci',
#   'LisaRosenbaum17',
#   'GileadSciences',
#   'gina_lundberg',
#   'DrJMarine',
#   'fitmslax',
#   'arghavan_salles'],
#  ['purviparwani',
#   'American_Heart',
#   'khurramn1',
#   'ASPCardio',
#   'HamidGhanbariMD',
#   'CVDH_journal',
#   'TJaredBunch',
#   'nmarrouche',
#   'S_NarayanMD',
#   'AmrFBarakat'],
#  ['purviparwani',
#   'athenapoppas',
#   'DanielJohnsrud',
#   'WomenAs1',
#   'DrSuzyFeigofsky',
#   'vbeadmd',
#   'keaglemd',
#   'aakriti_15',
#   'AfricaHeartMD',
#   'AnkurKalraMD'],
#  ['purviparwani',
#   'EstefaniaOS',
#   'OSUWexMed',
#   'jennlewey',
#   'DrSarahjZaman',
#   'KevinBSneed',
#   'paomorejon',
#   'gina_lundberg',
#   'DavidLBrownMD',
#   'danilorenzatti'],
#  ['purviparwani',
#   'UFJaxDeanHaley',
#   'Bravo__MD',
#   'NHMAmd',
#   'DrJayMohan',
#   'drjeffle',
#   'gmacscotland',
#   'beaverspharmd',
#   'EmoryJohnsCreek',
#   'jennlewey'],
#  ['purviparwani',
#   'PennMedNews',
#   'vbeadmd',
#   'nyulangone',
#   'Pooh_Velagapudi',
#   'ACCP',
#   'NitiCardio',
#   'HafizaKMD',
#   'GoRedForWomen',
#   'MVMadhavanMD'],
#  ['purviparwani',
#   'AliveCor',
#   'ethanjweiss',
#   'emoryheart',
#   'leahjohnMD',
#   'WomenAs1',
#   'vbeadmd',
#   'MVMadhavanMD',
#   'ash71us',
#   'DrKLindley'],
#  ['purviparwani',
#   'gstanchev',
#   'arghavan_salles',
#   'SAgarwalMD',
#   'DrToniyaSingh',
#   'puja_banka',
#   'mmamas1973',
#   'Allison_Dupont',
#   'DBelardoMD',
#   'ajaykirtane'],
#  ['purviparwani',
#   'BoydDamp',
#   'sri_adu',
#   'PennNudgeUnit',
#   'AkhilNarangMD',
#   'eemoin',
#   'danielalamasmd',
#   'emily_fri',
#   'ASE360',
#   'DrToniyaSingh'],
#  ['CrystalRun', 'CrystalRunJobs'],
#  ['CrystalRun', 'CrystalRunJobs'],
#  ['CrystalRun', 'CrystalRunJobs'],
#  ['CrystalRun', 'CrystalRunJobs'],
#  ['CrystalRun', 'CrystalRunJobs'],
#  ['CrystalRun', 'CrystalRunJobs'],
#  ['CrystalRun', 'CrystalRunJobs'],
#  ['CrystalRun', 'CrystalRunJobs'],
#  ['CrystalRun', 'CrystalRunJobs'],
#  ['CrystalRun', 'CrystalRunJobs'],
#  ['DocBerkes', 'AOC', 'MasalaBae_', 'DrDenaGrayson', 'manyban2'],
#  ['DocBerkes', 'AOC', 'MG00107680'],
#  ['DocBerkes', 'AOC', 'Janey05638384', 'AyannaPressley', 'Pinellas4Warren'],
#  ['DocBerkes', 'AOC', 'EDRN_Mommy_KP'],
#  ['DocBerkes', 'AOC', 'MabelGomes'],
#  ['DocBerkes', 'AOC', 'brityybee'],
#  ['DocBerkes', 'AOC', 'liviadrusilla90'],
#  ['DocBerkes', 'AOC', 'dolliod', 'lucasmorin_eolc'],
#  ['DocBerkes', 'AOC', 'DibeiChan'],
#  ['DocBerkes', 'AOC', 'gir_sus'],
#  ['khaleesi_atreyu', 'DrMarySLP', 'bear6613'],
#  ['khaleesi_atreyu', 'DrMarySLP', 'bear6613'],
#  ['khaleesi_atreyu', 'DrMarySLP', 'BGrueskin'],
#  ['khaleesi_atreyu', 'DrMarySLP', 'BGrueskin'],
#  ['khaleesi_atreyu', 'DrMarySLP', 'BGrueskin'],
#  ['khaleesi_atreyu', 'DrMarySLP', 'bear6613'],
#  ['khaleesi_atreyu', 'DrMarySLP', 'bear6613'],
#  ['khaleesi_atreyu', 'DrMarySLP', 'bear6613'],
#  ['khaleesi_atreyu', 'DrMarySLP', 'bear6613'],
#  ['khaleesi_atreyu', 'DrMarySLP', 'bear6613'],
#  ['MichaelTremmel', 'AOC', 'diane_dewald'],
#  ['MichaelTremmel', 'AOC', 'fancybob'],
#  ['MichaelTremmel', 'AOC', 'RNNext'],
#  ['MichaelTremmel', 'AOC', 'gyymjunkie', 'MsPackyetti', 'TylrMde'],
#  ['MichaelTremmel',
#   'AOC',
#   'Katcam1066',
#   'BillKristol',
#   'Dr_Ed_L',
#   'eugenegu',
#   '1darkotherside',
#   'ericlo'],
#  ['MichaelTremmel', 'AOC', 'Totalwellnessbr'],
#  ['MichaelTremmel', 'AOC', 'DharmaBum62'],
#  ['MichaelTremmel', 'AOC', 'INurse22'],
#  ['MichaelTremmel', 'AOC', 'raidrz07'],
#  ['MichaelTremmel',
#   'AOC',
#   'DarbyPhillipps',
#   'American_Heart',
#   'DrSherineSalib',
#   'CircRes',
#   'DrRGJonesLab',
#   'vasc_med',
#   'EbruErbayLab',
#   'AgingSciTalks'],
#  ['pbs',
#   'kellyclose',
#   'PhRMA',
#   'YatDeb',
#   'GarwoodStevens',
#   'janetwooten1',
#   'LillyPad',
#   'InsulinpumpM',
#   'Tidepool_org'],
#  ['pbs', 'kellyclose', 'IsletTx'],
#  ['pbs', 'arjun42', 'PhRMA', 'YatDeb', 'steveubl'],
#  ['pbs',
#   'arjun42',
#   'chickiepilot',
#   'kellyclose',
#   'lollydaggle',
#   'DrLearnALot',
#   'mattie_az'],
#  ['pbs',
#   'kellyclose',
#   'phrma',
#   'MDEckersley',
#   'Kidfears99',
#   'Rage_against_it',
#   'LillyPad',
#   'GoDiabetesMD',
#   'bernardkhoo'],
#  ['pbs',
#   'arjun42',
#   'chickiepilot',
#   'kellyclose',
#   'LillyPad',
#   'lvingfree5678',
#   'kylegriffin1',
#   'janetwooten1',
#   'cloudess',
#   'LoriRuder'],
#  ['pbs',
#   'kellyclose',
#   'DCinsulin4all',
#   'arjun42',
#   'Kidfears99',
#   'MsNerdyNurse'],
#  ['pbs',
#   'arjun42',
#   'chickiepilot',
#   'kellyclose',
#   'AmDiabetesAssn',
#   'JBlanchetteCDE',
#   'thomscher',
#   'RepAnthonyBrown',
#   'LillyDiabetes',
#   'shyredmd'],
#  ['pbs',
#   'kellyclose',
#   'diaTribeNews',
#   'mikesbkelly',
#   'DiabetesMine',
#   'TxPharmD',
#   'DianaMIsaacs',
#   'ASHPOfficial'],
#  ['pbs',
#   'kellyclose',
#   'Kidfears99',
#   'MDEckersley',
#   'phrma',
#   'arjun42',
#   'DCinsulin4all',
#   'ginger_annEdD',
#   'LillyPad',
#   'TheAACE'],
#  ['timkmak',
#   'DrDeb_DVM',
#   'maxxx__power',
#   'Dmozaffarian',
#   'gpokmd',
#   'gtsayer',
#   'SinghVasvi',
#   'GarimaVSharmaMD',
#   'HeartOTXHeartMD',
#   'hsafaMD'],
#  ['timkmak',
#   'SBakerMD',
#   'moreyraortho',
#   'samiinkinen',
#   'KetoDocCLT',
#   'ascarbs',
#   'drandyphung',
#   'DrSeanOMara',
#   'strongkatymay',
#   'BrianLenzkes'],
#  ['timkmak',
#   'SBakerMD',
#   'AAOSAdvocacy',
#   'drcateshanahan',
#   'RobertKennedyJr',
#   'CarnivoreMD',
#   'JRubinBlogger',
#   'ArnonKrongrad',
#   'TamarHaspel',
#   'DrKbythebay'],
#  ['timkmak',
#   'Dmozaffarian',
#   'escardio',
#   'tiffchenMD',
#   'OscarJMitchell',
#   'FSilvestryMD',
#   'purviparwani',
#   'cardionerds',
#   'drstaceyrosen',
#   'AMarshallMD'],
#  ['timkmak',
#   'SBakerMD',
#   'DrHorwitz',
#   'EricaHauver',
#   'DrRobDavidson',
#   'docrocktex26',
#   'AyannaPressley',
#   'pegues_beryl',
#   'AOC',
#   'dr_zmhaddad'],
#  ['timkmak',
#   'Dmozaffarian',
#   'heartdocandcrew',
#   'TCTMD_Yael',
#   'CMichaelGibson',
#   'EugeniaGianos',
#   'OSUWexMed',
#   'DLBHATTMD',
#   'TXmommydoc',
#   'Pooh_Velagapudi'],
#  ['timkmak', 'Dmozaffarian', 'SBakerMD', '4lisaguerrero', 'DrDeb_DVM', 'csd'],
#  ['timkmak',
#   'SBakerMD',
#   '4lisaguerrero',
#   'Dmozaffarian',
#   'PIH',
#   'HimadKhattak',
#   'ajaykirtane',
#   'tigranmd',
#   'ShelbyKuttyMD',
#   'joliebritt'],
#  ['timkmak', 'DrDeb_DVM', 'FlagGirlUSA', 'Dmozaffarian', 'vanvlietphd'],
#  ['timkmak',
#   'DrDeb_DVM',
#   'FlagGirlUSA',
#   'SBakerMD',
#   'drjasonfung',
#   'michaelwoodhci',
#   'bigfatsurprise',
#   'bschermd',
#   'tednaiman',
#   'KetoDocCLT'],
#  ['fxp123', 'debbie_dease', 'annedeuceofcups'],
#  ['fxp123', 'KSHopkins333'],
#  ['fxp123', 'debbie_dease', 'youdontknowdrek'],
#  ['fxp123', 'KSHopkins333'],
#  ['fxp123', 'KSHopkins333'],
#  ['fxp123', 'KSHopkins333'],
#  ['fxp123', 'KSHopkins333'],
#  ['fxp123', 'KSHopkins333'],
#  ['fxp123', 'KSHopkins333'],
#  ['fxp123', 'KSHopkins333'],
#  ['anthonyjonesmd'],
#  ['anthonyjonesmd'],
#  ['anthonyjonesmd'],
#  ['anthonyjonesmd'],
#  ['anthonyjonesmd'],
#  ['anthonyjonesmd'],
#  ['anthonyjonesmd'],
#  ['anthonyjonesmd'],
#  ['anthonyjonesmd'],
#  ['anthonyjonesmd'],
#  ['andrewjohnsmd',
#   'cjchiu',
#   'JoeySalibaMD',
#   'OhioStateIMRes',
#   'RRBaligaMD',
#   'doximity',
#   'sandeepdasmd',
#   'BrighamWomens',
#   'marstonMD',
#   'patrick_ellinor'],
#  ['andrewjohnsmd',
#   'cjchiu',
#   'RRBaligaMD',
#   'SocietyHospMed',
#   'drelisabradley',
#   'JonathanWindram',
#   'MasriAhmadMD',
#   'SmadarKort',
#   'jelevenson',
#   'UMMC'],
#  ['andrewjohnsmd',
#   'cjchiu',
#   'OhioStateIMRes',
#   'JoeySalibaMD',
#   'RRBaligaMD',
#   'josephahill',
#   'SocietyHospMed',
#   'keaglemd',
#   'DrAmirKaki',
#   'kwoolfmd'],
#  ['andrewjohnsmd',
#   'OhioStateIMRes',
#   'JoeySalibaMD',
#   'RRBaligaMD',
#   'keaglemd',
#   'gina_lundberg',
#   'StanCVFellows',
#   'GuruKowlgi',
#   'CardiologyToday',
#   'cardioPCImom'],
#  ['andrewjohnsmd',
#   'JoeySalibaMD',
#   'cjchiu',
#   'OhioStateIMRes',
#   'RRBaligaMD',
#   'PeterMohler',
#   'JSlivnickMD',
#   'DrQuinnCapers4',
#   'JoeBabaian',
#   'ShafkatAnwar'],
#  ['andrewjohnsmd',
#   'JoeySalibaMD',
#   'OhioStateIMRes',
#   'cjchiu',
#   'RRBaligaMD',
#   'BrighamFellows',
#   'tmmichelangelo',
#   'SarnoffCardio',
#   'DrHelenECollin1',
#   'LouDiabObese'],
#  ['andrewjohnsmd',
#   'cjchiu',
#   'RRBaligaMD',
#   'doximity',
#   'DLBHATTMD',
#   'Almanfi_Cardio',
#   'Drroxmehran',
#   'lucreciamburgos',
#   'MDEdgeTweets',
#   'ozlembilen2'],
#  ['andrewjohnsmd',
#   'RRBaligaMD',
#   'Apple',
#   'RonBlankstein',
#   'RakheeBhayaniMD',
#   'DrToniyaSingh',
#   'VUMC_MD',
#   'DBelardoMD',
#   'ersied727',
#   'DrJenniferCo_Vu'],
#  ['andrewjohnsmd',
#   'JoeySalibaMD',
#   'OhioStateIMRes',
#   'RRBaligaMD',
#   'keaglemd',
#   'DrArgyle',
#   'SBRT_CR',
#   'hjluks',
#   'f_l_o_u_r_i_s_h',
#   'EricTopol'],
#  ['andrewjohnsmd',
#   'cjchiu',
#   'OhioStateIMRes',
#   'JoeySalibaMD',
#   'RRBaligaMD',
#   'BrighamFellows',
#   'DrJayMohan',
#   'EMRAnswers',
#   'DrJenniferCo_Vu',
#   'drzgezdentok1'],
#  ['scottisaacsmd',
#   'evebmd',
#   'TheEndoSociety',
#   'tprhawk',
#   'nunoraimundo',
#   'phdgprotein86',
#   'uiowa',
#   'DrHelenECollin1',
#   'LouDiabObese'],
#  ['scottisaacsmd', 'evebmd', 'SenatorLoeffler'],
#  ['scottisaacsmd', 'evebmd', 'SenatorLoeffler'],
#  ['scottisaacsmd', 'evebmd', 'SenatorLoeffler'],
#  ['scottisaacsmd', 'evebmd', 'SenatorLoeffler'],
#  ['scottisaacsmd',
#   'evebmd',
#   'TheEndoSociety',
#   'ReeseRandle',
#   'TheAACE',
#   'RonBlankstein',
#   'Gayle52',
#   'AnkurKalraMD',
#   'adityadoc1',
#   'dmljmd'],
#  ['scottisaacsmd',
#   'evebmd',
#   'TheEndoSociety',
#   'DLBHATTMD',
#   'iamritu',
#   'aakriti_15',
#   'SaintJosephsATL',
#   'drmaggarwal',
#   'mmerschel',
#   'edwardmillermd'],
#  ['scottisaacsmd',
#   'evebmd',
#   'TheEndoSociety',
#   'Nimeri_MD',
#   'DLBHATTMD',
#   'AmDiabetesAssn',
#   'RonBlankstein',
#   'jgranadacrf',
#   'drjeffle',
#   'heartcurrents'],
#  ['scottisaacsmd', 'evebmd', 'SenatorLoeffler'],
#  ['scottisaacsmd', 'evebmd', 'SenatorLoeffler'],
#  ['mellody_dacruz', 'MsPackyetti', 'roddy_wllms', 'AOC', 'paddlebearer'],
#  ['mellody_dacruz', 'MsPackyetti', 'crypticbrunette'],
#  ['mellody_dacruz', 'MsPackyetti', 'taliaboo17'],
#  ['mellody_dacruz',
#   'MsPackyetti',
#   'BeautifulPainn',
#   'Kaimandante',
#   '_Butter21',
#   'AyannaPressley',
#   'BeeBabiCakes',
#   'IcebergAk',
#   'rothsteinfirm'],
#  ['mellody_dacruz', 'MsPackyetti', 'DrAhadJr'],
#  ['mellody_dacruz',
#   'MsPackyetti',
#   'TheRNKyle',
#   'AOC',
#   'SusanLouisePay1',
#   'AyannaPressley',
#   'bameado1',
#   'tdouglaslawson'],
#  ['mellody_dacruz', 'MsPackyetti', 'phan1om_'],
#  ['mellody_dacruz', 'MsPackyetti', 'elizzosaurusrex'],
#  ['mellody_dacruz', 'MsPackyetti', 'BoriBoli2011'],
#  ['mellody_dacruz', 'MsPackyetti', 'DRxUGdealer'],
#  ['narceducator', 'GetHimOutNow'],
#  ['narceducator', 'GetHimOutNow'],
#  ['narceducator', 'GetHimOutNow'],
#  ['narceducator', 'GetHimOutNow'],
#  ['narceducator', 'GetHimOutNow'],
#  ['narceducator', 'GetHimOutNow'],
#  ['narceducator', 'GetHimOutNow'],
#  ['narceducator', 'GetHimOutNow'],
#  ['narceducator', 'GetHimOutNow'],
#  ['narceducator', 'GetHimOutNow'],
#  ['LouMitrevMD',
#   'scahq',
#   'skathire',
#   'rblument1',
#   'DoctorMarvelMD',
#   'ValleAlfonso',
#   'DrJayMohan',
#   'DrArgyle',
#   'TCTMD',
#   'jesse8850'],
#  ['LouMitrevMD',
#   'scahq',
#   'JCVAonline',
#   'ASE360',
#   'sasha_opo',
#   'nicomillard',
#   'LubertMD',
#   'CardiologyYoung',
#   'drmaggarwal',
#   'mpsotka'],
#  ['LouMitrevMD', 'scahq', 'skathire', 'ArjunBalarMD'],
#  ['LouMitrevMD', 'scahq', 'skathire', 'TravelRNStyle', 'thehill', 'alesblee'],
#  ['LouMitrevMD', 'scahq', 'yasdetmaldonado'],
#  ['LouMitrevMD',
#   'scahq',
#   'JCVAonline',
#   'skathire',
#   'ACCinTouch',
#   'davidperitzmd',
#   'BidmcCvi',
#   'KTamirisaMD',
#   'MKIttlesonMD',
#   'cardioPCImom'],
#  ['LouMitrevMD', 'scahq', 'yasdetmaldonado'],
#  ['LouMitrevMD', 'scahq', 'yasdetmaldonado'],
#  ['LouMitrevMD',
#   'scahq',
#   'JCVAonline',
#   'ASE360',
#   'KoushikReddyMD',
#   'DLBHATTMD',
#   'NanetteWenger',
#   'ddefariayeh',
#   'JGrapsa',
#   'GuruKowlgi'],
#  ['LouMitrevMD',
#   'scahq',
#   'skathire',
#   'Drroxmehran',
#   'GradyHealth',
#   'DrDebCroyNP',
#   'HFSA',
#   'purviparwani',
#   'NanditaScott',
#   'ggvela'],
#  ['marysch17',
#   'MsPackyetti',
#   'thatMeganRN',
#   'AyannaPressley',
#   'TheEIbows',
#   'JordanUhl',
#   'nursevictoria11',
#   'DBelardoMD',
#   'DrRyanPDaly',
#   'edwardmillermd'],
#  ['marysch17', 'MsPackyetti', 'ApexPredator_35'],
#  ['marysch17', 'MsPackyetti', 'peggydumptrump', 'DaveKeating'],
#  ['marysch17', 'MsPackyetti', 'erinbrocksmith'],
#  ['marysch17', 'MsPackyetti', 'NerdyPharmacist'],
#  ['marysch17', 'MsPackyetti', 'bizarroDF'],
#  ['marysch17', 'MsPackyetti', 'DarlingDestyni', 'IcebergAk', 'ColdbeerSteven'],
#  ['marysch17', 'MsPackyetti', 'christlang_'],
#  ['marysch17', 'MsPackyetti', 'asanchez_1923', 'IcebergAk', 'tySanti_'],
#  ['marysch17', 'MsPackyetti', 'DreamTheDare'],
#  ['TexanLady40',
#   'Shakkh1r',
#   'Eugene_Robinson',
#   'earlydetectdoc',
#   'staceyabrams'],
#  ['TexanLady40', 'Shakkh1r', 'MSNBC', 'perry46_Shirley', 'NadlerJanet'],
#  ['TexanLady40', 'Shakkh1r', 'MSNBC', 'ChristianDem47', 'lt4agreements'],
#  ['TexanLady40', 'Shakkh1r', 'MosiBundu'],
#  ['TexanLady40',
#   'Shakkh1r',
#   'MSNBC',
#   'perry46_Shirley',
#   'CNN',
#   'Beth17459893',
#   'crampell'],
#  ['TexanLady40', 'Shakkh1r', 'chrisgoodman814'],
#  ['TexanLady40', 'Shakkh1r', 'MSNBC', 'CuddleBear76', 'allinwithchris'],
#  ['TexanLady40', 'Shakkh1r', 'chrisgoodman814'],
#  ['TexanLady40', 'Shakkh1r', 'Eugene_Robinson', 'earlydetectdoc', 'HUPrez17'],
#  ['TexanLady40',
#   'Shakkh1r',
#   'MSNBC',
#   'barbarabwatkins',
#   'American_Heart',
#   'DrMichelIbrahim',
#   'AnkurKalraMD',
#   'GoRedForWomen',
#   'DocElovitz',
#   'uche_blackstock'],
#  ['LCunninghamMD',
#   'ishlt',
#   'NirUrielMD',
#   'UUcvsl',
#   'AmiBhattMD',
#   'geoffrey_rubin',
#   'AnumSaeedMD',
#   'athenapoppas',
#   'DrMonikaSchmidt',
#   'ACCinTouch'],
#  ['LCunninghamMD',
#   'ishlt',
#   'AnkurKalraMD',
#   'CincyChildrens',
#   'purviparwani',
#   'Docbasia',
#   'skathire',
#   'MinnowWalsh',
#   'SusanJosephMD',
#   'RaulWeiss6'],
#  ['LCunninghamMD',
#   'ishlt',
#   'AnkurKalraMD',
#   'heartrct',
#   'DrRosanel',
#   'abrahahailu',
#   'FaheemYounus',
#   'adamscrabble',
#   'CatActExpert',
#   'Newsweek'],
#  ['LCunninghamMD',
#   'ishlt',
#   'RanLeeMD',
#   'BrettSperryMD',
#   'NLAWIL',
#   'skilicmd',
#   'Almanfi_Cardio',
#   'MahazarinG',
#   'drladyheart',
#   'DoctorLatina'],
#  ['LCunninghamMD',
#   'ishlt',
#   'SusanJosephMD',
#   'HeartBobH',
#   'DeeDeeWangMD',
#   'RBP0612',
#   'Pooh_Velagapudi',
#   'RickyHansra',
#   'Fentanes_MD',
#   'RFontesCarvalho'],
#  ['LCunninghamMD',
#   'ishlt',
#   'shwinner',
#   'HFSA',
#   'SharonneHayes',
#   'AHAMeetings',
#   'DocElovitz',
#   'nyugrossman',
#   'drladyheart',
#   'LAuroraMD'],
#  ['LCunninghamMD',
#   'ishlt',
#   'datsunian',
#   'HenrytTimothy',
#   'dehghani_payam',
#   'SriPittaMD',
#   'igeorge1975'],
#  ['LCunninghamMD',
#   'ishlt',
#   'NirUrielMD',
#   'Cardiology',
#   'RBP0612',
#   'Oregonian',
#   'anish_koka',
#   'timothygirard',
#   'AshvinPande',
#   'doctorwes'],
#  ['LCunninghamMD',
#   'ishlt',
#   'NirUrielMD',
#   'AHAScience',
#   'WCL92689433',
#   'MattWalshBlog',
#   'HDatawonk'],
#  ['LCunninghamMD',
#   'ishlt',
#   'tonkhueMdPhd',
#   'AndrewHigginsMD',
#   'ImpulseDynMD',
#   'MKIttlesonMD',
#   'FudimMarat',
#   'JasonKatzMD',
#   'DrClaudiusMahr',
#   'concernecus'],
#  ['drjohnm',
#   'mmamas1973',
#   'DrKLindley',
#   'SAgarwalMD',
#   'leahjohnMD',
#   'virani_md',
#   'WomenHeartOrg',
#   'gcfmd',
#   'HFpEF',
#   'tonkhueMdPhd'],
#  ['drjohnm',
#   'DrDarshanDoshi',
#   'HadyLichaaMD',
#   'RNarayanMD',
#   'atishmathurmd',
#   'KimAtianzar',
#   'RadialFirstBot',
#   'DrPRao',
#   'ajaykirtane',
#   'datsunian'],
#  ['drjohnm',
#   'DBelardoMD',
#   'ehj_ed',
#   'KTamirisaMD',
#   'Almanfi_Cardio',
#   'aairaqiSCAI',
#   'mpabrams',
#   'LubertMD',
#   'almeneisi',
#   'MasriAhmadMD'],
#  ['drjohnm',
#   'mpabrams',
#   'ASabanayagamMD',
#   'kejoynt',
#   'EugeniaGianos',
#   'EmoryMedicine',
#   'jesse8850',
#   'NanetteWenger',
#   'ddefariayeh',
#   'DrAdaStefanescu'],
#  ['drjohnm',
#   'dr_chirumamilla',
#   'NirUrielMD',
#   'NIH',
#   'CardioOncology',
#   'onco_cardiology',
#   'edwardmillermd',
#   'drundrwd',
#   'DrJayMohan',
#   'JZArnautovic'],
#  ['drjohnm',
#   'EmoryJohnsCreek',
#   'jennlewey',
#   'ElizaMillerMD',
#   'KismetRasmu',
#   'ersied727',
#   'DrEugeneYang',
#   'DrTGupta',
#   'SusanHingle',
#   'HeartOTXHeartMD'],
#  ['drjohnm',
#   'jeffreygeske',
#   'SanjeevBhavnani',
#   'ACCinTouch',
# ...
#   'RBP0612',
#   'sahilparikhmd',
#   'AnkurKalraMD',
#   'DrJayMohan'],
#  ['ersied727',
#   'MVMadhavanMD',
#   'mirvatalasnag',
#   'AnumSaeedMD',
#   'cardioPCImom',
#   'AtriumHealth',
#   'a_l_bailey',
#   'CarlosdelRio7',
#   'DrLaxmiMehta',
#   'Nidhi_Madan9'],
#  ['ersied727',
#   'DaveDixonPharmD',
#   'MVMadhavanMD',
#   'HopkinsMedicine',
#   'DrClaudiusMahr',
#   'NMHheartdoc',
#   'mpsotka',
#   'SrivastavaPrat',
#   'DrSheilaSahni',
#   'KhandelwalMD'],
#  ['ersied727',
#   'drelisabradley',
#   'UN_Women',
#   'DrSuzyFeigofsky',
#   'NadeenFaza',
#   'MKIttlesonMD',
#   'mpsotka',
#   'Optimizer4CCM',
#   'SusanJosephMD',
#   'gcfmd'],
#  ['ersied727',
#   'DaveDixonPharmD',
#   'KidneyWars',
#   'michellebr00ks',
#   'AjayPMD',
#   'DrJaredDyer',
#   'JAMANeuro',
#   'Nimeshp7',
#   'AbbateAntonio',
#   'mkmojadidi'],
#  ['ersied727',
#   'Pooh_Velagapudi',
#   'dranulala',
#   'ErinMichos',
#   'UBatnyam',
#   'DocSavageTJU',
#   'sandeepdasmd',
#   'CiccaroneCenter',
#   'spjuraschek',
#   'AHAMeetings'],
#  ['ersied727',
#   'KTamirisaMD',
#   'ShahzebKhanMD',
#   'DrMarthaGulati',
#   'DrRosanel',
#   'HafizaKMD',
#   'CaliforniaACC',
#   'HeartBobH',
#   'rladeiraslopes',
#   'RonBlankstein'],
#  ['ersied727',
#   'BrenerMickey',
#   'NYPCUCVI',
#   'drdlascano',
#   'NirUrielMD',
#   'datsunian',
#   'Drroxmehran',
#   'hahn_rt',
#   'shwinner',
#   'ImpulseDynMD'],
#  ['ersied727',
#   'beaverspharmd',
#   'CardiologyToday',
#   'PradTummala',
#   'JAMANetworkOpen',
#   'NirUrielMD',
#   'SinghVasvi',
#   'CircImaging',
#   'DrMarthaGulati',
#   'krishnapatel888'],
#  ['UChicagoMed',
#   'DLBHATTMD',
#   'ClaireDuvernoy',
#   'DrJenniferCo_Vu',
#   'EmoryJohnsCreek',
#   'DaveDixonPharmD',
#   'Latinx16',
#   'gina_lundberg',
#   'HeartOTXHeartMD',
#   'dr_chirumamilla'],
#  ['UChicagoMed',
#   'gcfmd',
#   'yaleHFdoc',
#   'NirUrielMD',
#   'AHAScience',
#   'JackieLGreenMD',
#   'HopkinsMedicine',
#   'KTamirisaMD',
#   'BidmcCvi',
#   'AmericanHeartJ'],
#  ['UChicagoMed',
#   'gcfmd',
#   'tonkhueMdPhd',
#   'AHAScience',
#   'DavidWienerMD',
#   'ArgaizR',
#   'NHLBI_Translate',
#   'JAMACardio',
#   'mswami001',
#   'DocSavageTJU'],
#  ['UChicagoMed',
#   'AnnGageMD',
#   'DeanOrnishMD',
#   'VuMedi',
#   'CafriCarlos',
#   'james_saine',
#   'ACCinTouch',
#   'DrSafarova',
#   'JuneWRhee',
#   'HanZhuMD'],
#  ['UChicagoMed',
#   'Will_A_Huang',
#   'cardioPCImom',
#   'edwardmillermd',
#   'DavidLBrownMD',
#   'heartdoc45',
#   'DrJJJavier',
#   'djc795',
#   'bnallamo',
#   'MasriAhmadMD'],
#  ['UChicagoMed',
#   'cardioPCImom',
#   'JonathanDavisHF',
#   'SunitChaudhryMD',
#   'NYPCUCVI',
#   'DaveDixonPharmD',
#   'COvertonMD',
#   'jaideeppatelmd',
#   'chrisLyoungmd',
#   'AudreyBJernigan'],
#  ['UChicagoMed',
#   'DLBHATTMD',
#   'BabsElectrical2',
#   'datsunian',
#   'DrJJJavier',
#   'matheenkhuddus',
#   'heartdoc45',
#   'MKIttlesonMD',
#   'HenrytTimothy',
#   'Dr_BowTie65'],
#  ['UChicagoMed',
#   'DrMarthaGulati',
#   'KevinShahMD',
#   'Nishant_ShahMD',
#   'CCFcards',
#   'DrJMieres',
#   'SVRaoMD',
#   'AakShahMD',
#   'MBalghith',
#   'ozlembilen2'],
#  ['UChicagoMed',
#   'drjohnm',
#   'HadyLichaaMD',
#   'cardionerds',
#   'DrKLindley',
#   'UN_Women',
#   'DrSuzyFeigofsky',
#   'AHAScience',
#   'DaktariJay',
#   'AssaadIqbal'],
#  ['UChicagoMed',
#   'gcfmd',
#   'shivkumarmd',
#   'AndrewJSauer',
#   'mw_sherwood',
#   'HeartBobH',
#   'NLAWIL',
#   'cardioPCImom',
#   'Cosyns',
#   'FiRSTSCCT'],
#  ['robocatdan', 'hubbardbradford', '_iEndo'],
#  ['robocatdan', 'hubbardbradford', 'GlenPPatterson'],
#  ['robocatdan', 'hubbardbradford', 'lisaporter555'],
#  ['robocatdan', 'hubbardbradford', 'CFlamos'],
#  ['robocatdan', 'hubbardbradford', 'GlenPPatterson'],
#  ['robocatdan', 'hubbardbradford', 'renee_holz'],
#  ['robocatdan', 'hubbardbradford', 'renee_holz'],
#  ['robocatdan', 'hubbardbradford', 'Genelle029'],
#  ['robocatdan', 'hubbardbradford', 'MichelleSapsed'],
#  ['robocatdan', 'hubbardbradford', 'renee_holz'],
#  ['cardiacinterv',
#   'KimAtianzar',
#   'crfshj',
#   'djc795',
#   'DrToniyaSingh',
#   'SmadarKort',
#   'DanielJohnsrud',
#   'HeartBobH',
#   'Cardiology',
#   'sasha_opo'],
#  ['cardiacinterv',
#   'KimAtianzar',
#   'DrMauricioCohen',
#   'RadialFirstBot',
#   'DrJayMohan',
#   'arnavkumar',
#   'hpatel824',
#   'Almanfi_Cardio',
#   'dranulala',
#   'basmahsaf'],
#  ['cardiacinterv',
#   'KimAtianzar',
#   'PouyanArman',
#   'RadialFirstBot',
#   'UjjwalRastogiMD',
#   'BidmcCvi',
#   'HFnursemaghee',
#   'ACCinTouch',
#   'adityadoc1',
#   'DoctorLatina'],
#  ['cardiacinterv',
#   'KimAtianzar',
#   'RadialFirstBot',
#   'Nidhi_Madan9',
#   'ACNAPPresident',
#   'adityadoc1',
#   'leahjohnMD',
#   'DrJayMohan',
#   'drelisabradley',
#   'alex_ditommaso'],
#  ['cardiacinterv',
#   'KimAtianzar',
#   'DrMauricioCohen',
#   'umiamimedicine',
#   'KaulP',
#   'Lross246',
#   'Drroxmehran',
#   'gmacscotland',
#   'KittyKatzMD',
#   'drahmedmohsen85'],
#  ['cardiacinterv',
#   'KimAtianzar',
#   'Babar_Basir',
#   'NidaQadirMD',
#   'iyadisseh',
#   'Allison_Dupont',
#   'JZArnautovic',
#   'DBelardoMD',
#   'yourheartdoc1',
#   'TCTMD'],
#  ['cardiacinterv',
#   'KimAtianzar',
#   'HadyLichaaMD',
#   'DrJayMohan',
#   'AHAScience',
#   'ddefariayeh',
#   'anudodejamd',
#   'HeartBobH',
#   'JourdieTMD',
#   'SamOJonesMD'],
#  ['cardiacinterv',
#   'KimAtianzar',
#   'DrAnkitKPatel',
#   'atishmathurmd',
#   'Almanfi_Cardio',
#   'DrDebCroyNP',
#   'aakriti_15',
#   'sandylewis',
#   'dbelardomd',
#   'DrRosanel'],
#  ['cardiacinterv',
#   'KimAtianzar',
#   'RadialFirstBot',
#   'arnavkumar',
#   'GlobalRabbi',
#   'sandylewis',
#   'Latinx16',
#   'DrQuinnCapers4',
#   'EmoryJohnsCreek',
#   'DrJayMohan'],
#  ['cardiacinterv',
#   'KimAtianzar',
#   'atishmathurmd',
#   'DrAnkitKPatel',
#   'HadyLichaaMD',
#   'iamritu',
#   'AnkurKalraMD',
#   'jgranadacrf',
#   'DrQuinnCapers4',
#   'BellevueHosp'],
#  ['DylanMacKayPhD', 'HormoneSynergy', 'AditiNerurkar'],
#  ['DylanMacKayPhD', 'HormoneSynergy', 'DrWhoReads'],
#  ['DylanMacKayPhD',
#   'HormoneSynergy',
#   'I_mitochondria',
#   'KetoDocCLT',
#   'theJeremyVine',
#   'CarnivoreMD',
#   'ifixhearts',
#   'BrianLenzkes',
#   'vision_quality',
#   'JakeKushnerMD'],
#  ['DylanMacKayPhD', 'HormoneSynergy', 'AditiNerurkar'],
#  ['DylanMacKayPhD', 'HormoneSynergy', 'ariannahuff'],
#  ['DylanMacKayPhD', 'HormoneSynergy', 'AditiNerurkar'],
#  ['DylanMacKayPhD',
#   'HormoneSynergy',
#   'I_mitochondria',
#   'janisswb',
#   'FatEmperor',
#   'LoriAMoore53',
#   'DNSWilson'],
#  ['DylanMacKayPhD',
#   'HormoneSynergy',
#   'I_mitochondria',
#   'michaelwoodhci',
#   'SimmonsBart',
#   'RobertLustigMD',
#   'HSELive',
#   'MollyMully',
#   'Nestle'],
#  ['DylanMacKayPhD', 'HormoneSynergy', 'AditiNerurkar'],
#  ['DylanMacKayPhD', 'HormoneSynergy', 'DrWhoReads'],
#  ['kentuckyacc',
#   'TriHealth',
#   'CincyKidsHeart',
#   'MasriAhmadMD',
#   'TCTMD',
#   'NirUrielMD',
#   'RaulWeiss6',
#   'iamritu',
#   'manesh_patelMD',
#   'AHAScience'],
#  ['kentuckyacc',
#   'LubertMD',
#   'anastaqa',
#   'therealjonadill',
#   'ShafkatAnwar',
#   'rajdoc2005',
#   'Nidhi_Madan9',
#   'NanditaCGupta1',
#   'DaveDixonPharmD',
#   'MGHHeartHealth'],
#  ['kentuckyacc',
#   'TriHealth',
#   'WSchnettler',
#   'sasha_opo',
#   'ChristHospital',
#   'LubertMD',
#   'rajdoc2005',
#   'DrJenniferCo_Vu',
#   'paomorejon',
#   'drstaceyrosen'],
#  ['kentuckyacc',
#   'LubertMD',
#   'AriCedars',
#   'aakriti_15',
#   'ElaineWanMD',
#   'aairaqiSCAI',
#   'hahn_rt',
#   'LisaRosenbaum17',
#   'PennMedNews',
#   'DrMarthaGulati'],
#  ['kentuckyacc',
#   'LubertMD',
#   'PHNresearch',
#   'devyanichowdhu1',
#   'DistyPearson',
#   'purviparwani',
#   'AnkurKalraMD',
#   'AHAMeetings',
#   'RyanTedfordMD',
#   'PradTummala'],
#  ['kentuckyacc',
#   'TriHealth',
#   'SamWittekind',
#   'PushpaShivaram',
#   'APAC_Cardiology',
#   'avolgman',
#   'emoryheart',
#   'Babar_Basir',
#   'TXmommydoc',
#   'cardioPCImom'],
#  ['kentuckyacc',
#   'LubertMD',
#   'ACCinTouch',
#   'HaoyiZhengMD',
#   'radcliffeCARDIO',
#   'avolgman',
#   'hvanspall',
#   'DrJenniferCo_Vu',
#   'juancplana',
#   'gina_lundberg'],
#  ['kentuckyacc',
#   'LubertMD',
#   'FeliciaEichelb1',
#   'FredWuMD',
#   'CardioOncology',
#   'inacc',
#   'DrMarthaGulati',
#   'ShadyHenienMD',
#   'UjjwalRastogiMD',
#   'arnavkumar'],
#  ['kentuckyacc',
#   'LubertMD',
#   'DLSM_MD',
#   'PushpaShivaram',
#   'jeffreygeske',
#   'purviparwani',
#   'NPCQIC',
#   'DrMarthaGulati',
#   'venkmurthy',
#   'DrAseemMalhotra'],
#  ['kentuckyacc',
#   'LubertMD',
#   'FeliciaEichelb1',
#   'MasriAhmadMD',
#   'StanfordChild',
#   'AlsaiedTarek',
#   'drelisabradley',
#   'aakriti_15',
#   'NMHheartdoc',
#   'HeartOTXHeartMD'],
#  ['soofriends', 'LadyAg72', 'TeriCottone'],
#  ['soofriends', 'LadyAg72', 'lpray18'],
#  ['soofriends', 'LadyAg72', 'bonniez45'],
#  ['soofriends', 'OconnorPeggy', 'MrPetesonality', 'LadyAg72', 'browndotflop'],
#  ['soofriends', 'LadyAg72', 'HilaryKi'],
#  ['soofriends', 'LadyAg72', 'DL15277269'],
#  ['soofriends', 'OconnorPeggy', 'LadyAg72', 'StopBadDocs'],
#  ['soofriends', 'OconnorPeggy', 'MoogieMonsters', 'LadyAg72', 'RollinsLynda'],
#  ['soofriends', 'OconnorPeggy', 'Talkeetna101', 'LadyAg72', 'Bris516'],
#  ['soofriends', 'LadyAg72', 'SasTrendy'],
#  ['jennwilliamsnp',
#   'DrPaulMason',
#   'michaelwoodhci',
#   'RobertLustigMD',
#   'basiliskgpt6942',
#   'DrRobDavidson',
#   'TonyBurnetti',
#   'DrSamGirgis',
#   'lewistlc',
#   'monarchdiaries'],
#  ['jennwilliamsnp',
#   'DrPaulMason',
#   'KenDBerryMD',
#   'bigfatsurprise',
#   'Brookemillermd'],
#  ['jennwilliamsnp',
#   'DrPaulMason',
#   'SBakerMD',
#   'IMWHorvitz',
#   'gerdosi',
#   'ethanjweiss',
#   'MikeAlbertMD',
#   'TravelLightP1',
#   'ColleenHuberNMD',
#   'holmanm'],
#  ['jennwilliamsnp',
#   'DrPaulMason',
#   'DrHorwitz',
#   'EricaHauver',
#   'KenDBerryMD',
#   'the_alexpeace',
#   'jbmatta13',
#   'CarnivoreMD',
#   'WhiteHouse',
#   'RobertLustigMD'],
#  ['jennwilliamsnp',
#   'DrPaulMason',
#   'DrHorwitz',
#   'DikemanDave',
#   'IMWHorvitz',
#   'JakeKushnerMD',
#   'DrRamonIssa',
#   'gerdosi',
#   'bschermd',
#   'Dmozaffarian'],
#  ['jennwilliamsnp',
#   'DrPaulMason',
#   'DrHorwitz',
#   'its_tew',
#   'Wmdillon',
#   'CircAHA',
#   'Nidhi_Madan9',
#   'emoryhealthcare',
#   'DrKLindley',
#   'EmoryDeptofMed'],
#  ['jennwilliamsnp',
#   'DrPaulMason',
#   'drandyphung',
#   'JimJohnsonSci',
#   'PeterHotez',
#   'ty_the_np',
#   'trucker_mo'],
#  ['jennwilliamsnp',
#   'DrPaulMason',
#   'SBakerMD',
#   'meat_rx',
#   'DrDerek1015',
#   'CarnivoreMD',
#   'REALITYofJNJ',
#   'FaheemYounus',
#   'AfricaHeartMD',
#   'aakriti_15'],
#  ['jennwilliamsnp',
#   'DrPaulMason',
#   'SBakerMD',
#   'DrHorwitz',
#   'fancypirate8',
#   'IMWHorvitz',
#   'Kylieilie',
#   'CarnivoreMD',
#   'realDonaldTrump',
#   'GFarquart'],
#  ['jennwilliamsnp',
#   'DrPaulMason',
#   'juliejangles',
#   'KenDBerryMD',
#   'eatmostlyfatali',
#   'howardray4',
#   'WorldAndScience'],
#  ['KeyurBShahRIC',
#   'VCUHealthHeart',
#   'Dr_Mike_Stevens',
#   'JCVPOnline',
#   'SanChris999',
#   'DaveDixonPharmD',
#   'LauraLee714',
#   'jaideeppatelmd',
#   'johnwmcevoy',
#   'edwardmillermd'],
#  ['KeyurBShahRIC',
#   'vcuhealth',
#   'pduncan54',
#   'MarcoMetra',
#   'MDEdgeTweets',
#   'gmacscotland',
#   'DrJenniferCo_Vu',
#   'PamelaBMorris',
#   'SharonneHayes',
#   'ayaz_aghayev'],
#  ['KeyurBShahRIC',
#   'vcuhealth',
#   'DaveDixonPharmD',
#   'JCHillyard',
#   'jackpenner',
#   'DrJaredDyer',
#   'VCU_Nephrology',
#   'pranav_mankad',
#   'ArehzoJ',
#   'AudreyBJernigan'],
#  ['KeyurBShahRIC',
#   'vcuhealth',
#   'pduncan54',
#   'iamritu',
#   'pnatarajanmd',
#   'CircAHA',
#   'DrWanpen',
#   'MarkDrazner',
#   'DrDamluji',
#   'CDCgov'],
#  ['KeyurBShahRIC',
#   'vcuhealth',
#   'KevinBSneed',
#   'BidmcCvi',
#   'Pooh_Velagapudi',
#   'rajdoc2005',
#   'arghavan_salles',
#   'a_l_bailey',
#   'CloweMd',
#   'ggvela'],
#  ['KeyurBShahRIC',
#   'vcuhealth',
#   'pduncan54',
#   'sabeedak1',
#   'CardioOncology',
#   'drjameslo',
#   'DavidLBrownMD',
#   'lesleejshaw',
#   'DrRosanel',
#   'SkjaIdmaer'],
#  ['KeyurBShahRIC',
#   'vcuhealth',
#   'KevinBSneed',
#   'CrismonUTCOP',
#   'pduncan54',
#   'krithicism',
#   'cardioPCImom',
#   'heartdoc44',
#   'Tabaza',
#   'jpirruccello'],
#  ['KeyurBShahRIC',
#   'VCUHealthHeart',
#   'pduncan54',
#   'heartcurrents',
#   'AakShahMD',
#   'crfheart',
#   'HafizaKMD',
#   'kcferdmd',
#   'Drroxmehran',
#   'TCTMD_Yael'],
#  ['KeyurBShahRIC',
#   'VCUHealthHeart',
#   'AudreyBJernigan',
#   'bqueenhoo',
#   'jaideeppatelmd',
#   'chrisLyoungmd',
#   'michellebr00ks',
#   'DaveDixonPharmD',
#   'jesse8850',
#   'chiarabd'],
#  ['KeyurBShahRIC',
#   'vcuhealth',
#   'DaveDixonPharmD',
#   'leahjohnMD',
#   'RBP0612',
#   'ErinMichos',
#   'skilicmd',
#   'mswami001',
#   'AChoiHeart',
#   'DocStrom'],
#  ['FOX9',
#   'skathire',
#   'ABCardio1',
#   'TCTMD_Yael',
#   'drlouisesegan',
#   'jennlewey',
#   'JJRyanMD',
#   'a_l_bailey',
#   'DrJMieres',
#   'colleenmfarrell'],
#  ['FOX9',
#   'wisit661',
#   'BWHKidney',
#   'skathire',
#   'escardio',
#   'DrJRums',
#   'kwoolfmd',
#   'AndreGauri'],
#  ['FOX9',
#   'anamarialopezmd',
#   'MayoClinic',
#   'TomasNeilan',
#   'keaglemd',
#   'bishcards',
#   'noshreza',
#   'TolaniSonia',
#   'sahilparikhmd',
#   'HafizaKMD'],
#  ['FOX9', 'skathire', 'NPDANN'],
#  ['FOX9', 'anamarialopezmd', 'UofUHealth', 'MichLitch', 'ScottSummers339'],
#  ['FOX9',
#   'skathire',
#   'fitmslax',
#   'ShelbyKuttyMD',
#   'ShafkatAnwar',
#   'CMichaelGibson',
#   'RRBaligaMD',
#   'DLBhattMD',
#   'rkwadhera',
#   'BIDMChealth'],
#  ['FOX9',
#   'skathire',
#   'mchonig',
#   'JudyHungMD',
#   'ddefariayeh',
#   'DrJMieres',
#   'arghavan_salles',
#   'evankirstel',
#   'mjnickolaus',
#   'ACHA_Heart'],
#  ['FOX9',
#   'wisit661',
#   'MGHKidneys',
#   'skathire',
#   'Sued0595',
#   'mirvatalasnag',
#   'gcfmd',
#   'Kelsey_C_Martin',
#   'Babar_Basir',
#   'NancyatHeart'],
#  ['FOX9', 'anamarialopezmd', 'michlitch', 'MichLitch', 'UofUHealth'],
#  ['FOX9',
#   'wisit661',
#   'LVRiella',
#   'skathire',
#   'Pooh_Velagapudi',
#   'Babar_Basir',
#   'purviparwani',
#   'CincyKidsHeart',
#   'PushpaShivaram',
#   'Lross246'],
#  ['FOX13News', 'ChrisM_RN23'],
#  ['FOX13News', 'ChrisM_RN23'],
#  ['FOX13News', 'ChrisM_RN23'],
#  ['FOX13News', 'ChrisM_RN23'],
#  ['FOX13News', 'ChrisM_RN23'],
#  ['FOX13News', 'ChrisM_RN23'],
#  ['FOX13News', 'ChrisM_RN23'],
#  ['FOX13News', 'ChrisM_RN23'],
#  ['FOX13News', 'ChrisM_RN23'],
#  ['FOX13News', 'ChrisM_RN23'],
#  ['DonnaShelley2',
#   'JohnLoc35919363',
#   'itsJeffTiedrich',
#   'paddystash',
#   'real_squeeze'],
#  ['DonnaShelley2', 'JohnLoc35919363', 'CNN', 'DanBerky', 'cbn2'],
#  ['DonnaShelley2',
#   'JohnLoc35919363',
#   'itsJeffTiedrich',
#   'RhettBMurray1',
#   'LouisHorvath7'],
#  ['DonnaShelley2',
#   'JohnLoc35919363',
#   'realDonaldTrump',
#   'eswillwalker',
#   'jefposk',
#   'Laurie_Garrett',
#   'BermudezWrites',
#   'yayayarndiva',
#   'IlhanMN',
#   'handmaid_rn'],
#  ['DonnaShelley2', 'JohnLoc35919363', 'CNN', 'mvaval77'],
#  ['DonnaShelley2', 'JohnLoc35919363', 'CNN', 'piikupoika'],
#  ['DonnaShelley2',
#   'JohnLoc35919363',
#   'itsJeffTiedrich',
#   'RhettBMurray1',
#   'realDonaldTrump',
#   'drandyphung',
#   'bschermd',
#   'Dmozaffarian',
#   'GoHealio',
#   'hweintraubMD'],
#  ['DonnaShelley2', 'JohnLoc35919363', 'DotDotDot_John'],
#  ['DonnaShelley2', 'JohnLoc35919363', 'DotDotDot_John'],
#  ['DonnaShelley2',
#   'JohnLoc35919363',
#   'itsJeffTiedrich',
#   'RhettBMurray1',
#   'realDonaldTrump',
#   'brenda_luckow',
#   'harvestorg'],
#  ['mhdkabach',
#   'HimadKhattak',
#   'heartrct',
#   'DavidLBrownMD',
#   'Gayle52',
#   'DrMarthaGulati',
#   'SusanHingle',
#   'DrQuinnCapers4',
#   'MghScad',
#   'ASabanayagamMD'],
#  ['mhdkabach',
#   'HimadKhattak',
#   'Sudanheartgroup',
#   'DLBHATTMD',
#   'bcmhouston',
#   'ChiayuChenMD',
#   'PCSK9Forum',
#   'purviparwani',
#   'JACCJournals',
#   'KoushikReddyMD'],
#  ['mhdkabach',
#   'daytondailynews',
#   'RanLeeMD',
#   'AndrewHigginsMD',
#   'AnkurKalraMD',
#   'onco_cardiology',
#   'InduPartha',
#   'SamRRazaMD',
#   'DrJayMohan',
#   'NLAWIL'],
#  ['mhdkabach',
#   'daytondailynews',
#   'DenadaPalmMD',
#   'HimadKhattak',
#   'DrDapo',
#   'TCTMD',
#   'DrMichelIbrahim',
#   'mberenjiMD',
#   'PIH',
#   'mpsotka'],
#  ['mhdkabach',
#   'daytondailynews',
#   'DBelardoMD',
#   'hvanspall',
#   'hpatel824',
#   'Nidhi_Madan9',
#   'RickyHansra',
#   'DrTGupta',
#   'anjalid716',
#   'DrKLindley'],
#  ['mhdkabach',
#   'RadialFirstBot',
#   'SalmanWaheedMD',
#   'HimadKhattak',
#   'DoctorLatina',
#   'fitmslax',
#   'leahjohnMD',
#   'DougDrachmanMD',
#   'UjjwalRastogiMD',
#   'PCIsurgeon'],
#  ['mhdkabach',
#   'daytondailynews',
#   'DenadaPalmMD',
#   'HimadKhattak',
#   'Pooh_Velagapudi',
#   'ASabanayagamMD',
#   'VietHeartPA',
#   'gastropov',
#   'onco_cardiology',
#   'venkmurthy'],
#  ['mhdkabach',
#   'daytondailynews',
#   'FaheemYounus',
#   'WomanResistorNC',
#   'DFigoneMD',
#   'madeintulsa'],
#  ['mhdkabach',
#   'daytondailynews',
#   'emilyzernMD',
#   'DoctorLatina',
#   'ddefariayeh',
#   'gabyweissman',
#   'NicoleCruzMD',
#   'DrJCheungEP',
#   'erichorlick',
#   'NirUrielMD'],
#  ['mhdkabach',
#   'HimadKhattak',
#   'DrAdaStefanescu',
#   'MountSinaiNYC',
#   'DoctorCliffyy',
#   'WeillCornell',
#   'drtracykpaul',
#   'drprithas',
#   'SimranSinghMD',
#   'DrEHoman'],
#  ...]

# %%
# train skip-gram (word2vec) model
model = Word2Vec(window = 4, sg = 1, size = 100, hs = 0,negative = 10,alpha=0.03, min_alpha=0.0007,seed = 14)
#size of 100,200 and 300 dimensions were tested and out of which 100 dimension performed best in MultiView
model.build_vocab(random_walks, progress_per=2)
model.train(random_walks, total_examples = model.corpus_count, epochs=20, report_delay=1)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 11621/11621 [00:07<00:00, 1474.94it/s]
# 116210

# %%
#Creating Matrix that represent network based representation of the users and saving same for later use 
New_DF['NetworkEmbedding'] = [model[x['AUTHOR_ID']] for _,x in New_DF.iterrows()]
DeepWalkMat = np.zeros(300)
for _,x in New_DF.iterrows():
    DeepWalkMat = np.vstack((DeepWalkMat,x['NetworkEmbedding']))
DeepWalkMat = DeepWalkMat[1:,:]

# %%
Savefilepath = "C:/Users/SHAHBAZ/ZS UserEmbedding/AutoEncoderInputUserMatrix/"
fileName = Savefilepath + "DeepWalk_300_Matrix.txt"
np.savetxt(fileName,DeepWalkMat,fmt='%.8f')

# %%
#################################
### Updating the embedding #####

# %%
lis_org1_target1 = New_DF['Target_Connection'][420]   #existing user connecting

# %%
lis_org1_target1.extend(New_DF['Target_Connection'][270]) # new user connecting made during new window of time

# %%
### we will have to re build the graphs again afresh; 
### Creating graph and adding nodes###
G = nx.Graph()
for user in All_User:
    G.add_node(user)
    
for _,x in New_DF.iterrows():
    source = x['AUTHOR_ID']
    lis = x['Target_Connection']
    
    for target in lis:
        G.add_edge(source, target)

# %%
for target in lis_org1_target1: # adding updating new edges 
    G.add_edge('BrukeGetachew', target)

# %%
random_walks = []
for i in range(10):
    random_walks.append(get_randomwalk('BrukeGetachew',10))

# %%
#updating model
model.train(random_walks, total_examples = model.corpus_count, epochs=20, report_delay=1)
# Out:
# (8, 860)

# %%
#represent updated embedding
MatDeepWalkUpdate = np.zeros(100)
MatDeepWalkUpdate = np.vstack((MatDeepWalkUpdate,model['BrukeGetachew']))
MatDeepWalkUpdate = MatDeepWalkUpdate[1:,:]
